# %%
import torch
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
import os
import nltk
import string
from sympy.utilities.iterables import multiset_permutations

# %%
roberta = torch.hub.load('pytorch/fairseq', 'roberta.large')
# Out:
# Using cache found in C:\Users\bavik/.cache\torch\hub\pytorch_fairseq_master

# %%
data_dir = "./data/"
embed_size = 1024

# %%
requests = pd.read_table(data_dir + "train.tsv", sep = '\t', header = 0).drop_duplicates('topic_id')
df = pd.DataFrame(requests)
init_requests = df['initial_request'].to_numpy(dtype = str)
topic_ids = df['topic_id'].to_numpy(dtype = int)
clarification_need = df['clarification_need'].to_numpy(dtype = int)
req_data = [(topic_ids[i], init_requests[i], clarification_need[i]) for i in range(len(init_requests))]
req_data = np.array(req_data)
inputs = req_data[:,1]
labels = req_data[:,2]
topics = req_data[:,0]

# %%
inputs = np.array([req.lower() for req in inputs])
inputs = np.array([req.strip() for req in inputs])
inputs = np.array([req.translate(str.maketrans('', '', string.punctuation)) for req in inputs])
inputs = np.array([np.array(nltk.tokenize.word_tokenize(req)) for req in inputs])

# %%
inputs
# Out:
# array([array(['tell', 'me', 'about', 'obama', 'family', 'tree'], dtype='<U6'),
#        array(['what', 'is', 'fickle', 'creek', 'farm'], dtype='<U6'),
#        array(['tell', 'me', 'about', 'sonoma', 'county', 'medical', 'services'],
#       dtype='<U8'),
#        array(['tell', 'me', 'about', 'of', 'ralph', 'owen', 'brester'],
#       dtype='<U7'),
#        array(['im', 'looking', 'for', 'information', 'about', 'mayo', 'clinic',
#        'jacksonville', 'fl'], dtype='<U12'),
#        array(['how', 'to', 'prepare', 'for', 'the', 'gmat'], dtype='<U7'),
#        array(['id', 'like', 'to', 'learn', 'about', 'lymphoma', 'in', 'dogs'],
#       dtype='<U8'),
#        array(['is', 'kenmore', 'heater', 'good'], dtype='<U7'),
#        array(['tell', 'me', 'more', 'about', 'hp', 'mini', '2140'], dtype='<U5'),
#        array(['tell', 'me', 'about', 'the', 'pacific', 'northwest', 'laboratory'],
#       dtype='<U10'),
#        array(['what', 'is', 'california', 'franchise', 'tax', 'board'],
#       dtype='<U10'),
#        array(['what', 'are', 'specific', 'dangers', 'of', 'asbestos'],
#       dtype='<U8'),
#        array(['how', 'to', 'write', 'a', 'thank', 'you', 'letter', 'after', 'an',
#        'interview'], dtype='<U9'),
#        array(['how', 'to', 'hire', 'disc', 'jockey'], dtype='<U6'),
#        array(['tv', 'on', 'computer'], dtype='<U8'),
#        array(['tell', 'me', 'more', 'about', 'culpeper', 'national', 'cemetry'],
#       dtype='<U8'),
#        array(['tell', 'me', 'about', 'bowflex', 'power', 'pro'], dtype='<U7'),
#        array(['butter', 'and', 'margarine'], dtype='<U9'),
#        array(['im', 'looking', 'for', 'information', 'on', 'duchess', 'county',
#        'tourism'], dtype='<U11'),
#        array(['tell', 'me', 'information', 'about', 'iowas', 'food', 'stamp',
#        'program'], dtype='<U11'),
#        array(['map'], dtype='<U3'),
#        array(['what', 'is', 'equal', 'opportunity', 'employer'], dtype='<U11'),
#        array(['im', 'interested', 'in', 'mothers', 'day', 'songs'], dtype='<U10'),
#        array(['tell', 'me', 'about', 'source', 'of', 'the', 'nile'], dtype='<U6'),
#        array(['tell', 'me', 'about', 'american', 'military', 'university'],
#       dtype='<U10'),
#        array(['tell', 'me', 'about', 'rock', 'and', 'gem', 'shows'], dtype='<U5'),
#        array(['im', 'looking', 'for', 'information', 'on', 'jax', 'chemical',
#        'company'], dtype='<U11'),
#        array(['im', 'interested', 'in', 'dinosaurs'], dtype='<U10'),
#        array(['information', 'about', 'east', 'ridge', 'high', 'school'],
#       dtype='<U11'),
#        array(['how', 'to', 'register', 'dmv', 'in', 'va'], dtype='<U8'),
#        array(['tell', 'me', 'more', 'on', 'health', 'clubs', 'in', 'arkansas'],
#       dtype='<U8'),
#        array(['where', 'can', 'i', 'buy', 'a', 'trombone'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'vines', 'for', 'shade'], dtype='<U5'),
#        array(['what', 'can', 'i', 'do', 'in', 'sherwood', 'regional', 'library'],
#       dtype='<U8'),
#        array(['tell', 'me', 'about', 'tangible', 'personal', 'property', 'tax'],
#       dtype='<U8'),
#        array(['what', 'is', 'martha', 'stewart', 'and', 'imclone'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'uplift', 'at', 'yellowstone', 'national',
#        'park'], dtype='<U11'),
#        array(['give', 'me', 'espn', 'sports', 'information'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'pocono'], dtype='<U6'),
#        array(['figs'], dtype='<U4'),
#        array(['i', 'need', 'information', 'about', 'the', 'university', 'of',
#        'phoenix'], dtype='<U11'),
#        array(['how', 'should', 'i', 'use', 'the', 'septic', 'system', 'design'],
#       dtype='<U6'),
#        array(['find', 'information', 'on', 'porterville'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'about', 'game', 'and',
#        'fish', 'in', 'arizona'], dtype='<U11'),
#        array(['what', 'are', 'the', 'best', 'recepies', 'for', 'grilling'],
#       dtype='<U8'),
#        array(['tell', 'me', 'more', 'about', 'dnr'], dtype='<U5'),
#        array(['what', 'to', 'do', 'in', 'arkansas'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'barbados'], dtype='<U8'),
#        array(['what', 'are', 'the', 'causes', 'of', 'lipoma', 'tumors'],
#       dtype='<U6'),
#        array(['find', 'information', 'on', 'hip', 'fractures'], dtype='<U11'),
#        array(['what', 'are', 'signs', 'of', 'a', 'heartattack'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'weather', 'stripping'], dtype='<U9'),
#        array(['what', 'is', 'the', 'best', 'long', 'term', 'care', 'insurance'],
#       dtype='<U9'),
#        array(['tell', 'me', 'about', 'black', 'history'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'hotels', 'in', 'new', 'york'], dtype='<U6'),
#        array(['tell', 'me', 'about', 'kansas', 'city', 'mo'], dtype='<U6'),
#        array(['how', 'do', 'i', 'get', 'my', 'free', 'annual', 'credit',
#        'report'], dtype='<U6'),
#        array(['tell', 'me', 'about', 'unc'], dtype='<U5'),
#        array(['tell', 'me', 'about', 'vanuatu'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'internet', 'phone', 'serices'], dtype='<U8'),
#        array(['find', 'information', 'about', 'the', 'gs', 'pay', 'rate'],
#       dtype='<U11'),
#        array(['take', 'me', 'to', 'the', 'current'], dtype='<U7'),
#        array(['tell', 'me', 'information', 'about', 'a', 'sore', 'throat'],
#       dtype='<U11'),
#        array(['tell', 'me', 'about', 'idaho', 'state', 'flower'], dtype='<U6'),
#        array(['tell', 'me', 'more', 'about', 'indiana', 'state', 'fairgrounds'],
#       dtype='<U11'),
#        array(['tell', 'me', 'about', 'fybromyalgia'], dtype='<U12'),
#        array(['find', 'information', 'on', 'french', 'lick', 'resort', 'and',
#        'casino'], dtype='<U11'),
#        array(['tell', 'me', 'information', 'about', 'volvo'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'on', 'rick', 'warren'],
#       dtype='<U11'),
#        array(['what', 'is', 'yahoo'], dtype='<U5'),
#        array(['how', 'can', 'i', 'lower', 'my', 'heart', 'rate'], dtype='<U5'),
#        array(['im', 'interested', 'in', 'inuyasha'], dtype='<U10'),
#        array(['tell', 'me', 'about', 'ps', '2', 'games'], dtype='<U5'),
#        array(['how', 'to', 'get', 'organised'], dtype='<U9'),
#        array(['find', 'me', 'information', 'about', 'diabetes', 'education'],
#       dtype='<U11'),
#        array(['find', 'information', 'about', 'atari'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'on', 'web', 'design',
#        'and', 'hosting'], dtype='<U11'),
#        array(['find', 'information', 'about', 'elliptical', 'trainer'],
#       dtype='<U11'),
#        array(['tell', 'me', 'about', 'cell', 'phones'], dtype='<U6'),
#        array(['which', 'gps', 'receiver', 'i', 'should', 'buy'], dtype='<U8'),
#        array(['how', 'can', 'i', 'adopt', 'a', 'dog'], dtype='<U5'),
#        array(['give', 'me', 'information', 'about', 'disneyland', 'hotel'],
#       dtype='<U11'),
#        array(['how', 'to', 'change', 'the', 'toilet', 'in', 'the', 'house'],
#       dtype='<U6'),
#        array(['what', 'are', 'the', 'popular', 'jobs', 'in', 'michigan'],
#       dtype='<U8'),
#        array(['i', '’', 'm', 'looking', 'for', 'the', 'music', 'man'],
#       dtype='<U7'),
#        array(['find', 'information', 'about', 'the', 'secret', 'garden'],
#       dtype='<U11'),
#        array(['give', 'me', 'information', 'about', 'alexian', 'brothers',
#        'hospitals'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'wilson', 'antenna'], dtype='<U7'),
#        array(['im', 'looking', 'for', 'flame', 'designs'], dtype='<U7'),
#        array(['find', 'information', 'about', 'mitchell', 'college'],
#       dtype='<U11'),
#        array(['info', 'on', 'dog', 'heat'], dtype='<U4'),
#        array(['tell', 'me', 'about', 'avp'], dtype='<U5'),
#        array(['discovery', 'channel', 'store'], dtype='<U9'),
#        array(['im', 'looking', 'for', 'information', 'on', 'the', 'president',
#        'of', 'the', 'united', 'states'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'iron'], dtype='<U5'),
#        array(['tell', 'me', 'about', 'uss', 'yorktown', 'charleston', 'sc'],
#       dtype='<U10'),
#        array(['tell', 'me', 'about', 'ct', 'jobs'], dtype='<U5'),
#        array(['find', 'information', 'about', 'penguins'], dtype='<U11'),
#        array(['how', 'to', 'build', 'a', 'fence'], dtype='<U5'),
#        array(['tell', 'me', 'more', 'on', 'kansas', 'city', 'railroad'],
#       dtype='<U8'),
#        array(['tell', 'me', 'about', 'bellevue'], dtype='<U8'),
#        array(['i', '’', 'm', 'looking', 'for', 'information', 'on', 'worm'],
#       dtype='<U11'),
#        array(['find', 'information', 'about', 'flushing'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'korean', 'language'], dtype='<U8'),
#        array(['i', 'need', 'information', 'on', 'income', 'tax', 'return',
#        'online'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'on', 'vldl', 'levels'],
#       dtype='<U11'),
#        array(['find', 'me', 'information', 'about', 'pvc'], dtype='<U11'),
#        array(['find', 'sewing', 'instructions', 'for', 'me'], dtype='<U12'),
#        array(['to', 'be', 'or', 'not', 'to', 'be', 'that', 'is', 'the',
#        'question'], dtype='<U8'),
#        array(['find', 'information', 'about', 'the', 'sun'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'neil', 'young'], dtype='<U5'),
#        array(['find', 'information', 'about', 'tornadoes'], dtype='<U11'),
#        array(['information', 'about', 'bobcat'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'keyboard', 'reviews'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'afganistan'], dtype='<U10'),
#        array(['id', 'like', 'to', 'learn', 'about', 'joints'], dtype='<U6'),
#        array(['what', 'are', 'continental', 'plates'], dtype='<U11'),
#        array(['where', 'can', 'i', 'find', 'information', 'about', 'forearm',
#        'pain'], dtype='<U11'),
#        array(['give', 'me', 'information', 'on', 'ocd'], dtype='<U11'),
#        array(['i', 'am', 'looking', 'for', 'sources', 'of', 'used', 'car',
#        'parts'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'mgb'], dtype='<U5'),
#        array(['information', 'about', 'raffles'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'rice'], dtype='<U5'),
#        array(['im', 'looking', 'for', 'information', 'about', 'south', 'africa'],
#       dtype='<U11'),
#        array(['find', 'me', 'information', 'on', 'sat'], dtype='<U11'),
#        array(['tell', 'me', 'more', 'about', 'satilies'], dtype='<U8'),
#        array(['what', 'is', 'average', 'charitable', 'donation'], dtype='<U10'),
#        array(['what', 'is', 'madagascar', 'known', 'for'], dtype='<U10'),
#        array(['tell', 'me', 'about', 'kids', 'earth', 'day', 'activities'],
#       dtype='<U10'),
#        array(['what', 'was', 'electoral', 'college', '2008', 'results'],
#       dtype='<U9'),
#        array(['what', 'is', 'usda', 'food', 'pyramid'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'making', 'chicken', 'soup', 'from',
#        'scratch'], dtype='<U7'),
#        array(['i', 'will', 'survive', 'lyrics'], dtype='<U7'),
#        array(['tell', 'me', 'more', 'about', 'hawain', 'volcanos'], dtype='<U8'),
#        array(['what', 'are', 'the', 'seven', 'deadly', 'sins'], dtype='<U6'),
#        array(['im', 'looking', 'for', 'information', 'on', 'hurricane', 'irene',
#        'flooding', 'in', 'manville', 'nj'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'symptoms', 'of', 'mad', 'cow', 'disease',
#        'in', 'humans'], dtype='<U8'),
#        array(['lets', 'see', 'frank', 'lloyd', 'wright', 'biography'],
#       dtype='<U9'),
#        array(['how', 'to', 'use', 'wiki'], dtype='<U4'),
#        array(['tell', 'me', 'about', 'civil', 'war', 'battles', 'in', 'south',
#        'carolina'], dtype='<U8'),
#        array(['how', 'is', 'identifying', 'spider', 'bites'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'evidence', 'for', 'evolution'], dtype='<U9'),
#        array(['give', 'me', 'information', 'about', 'tribe', 'formerly',
#        'living', 'in', 'alabama'], dtype='<U11'),
#        array(['find', 'symptoms', 'of', 'heart', 'attack'], dtype='<U8'),
#        array(['how', 'can', 'i', 'view', 'my', 'internet', 'history'],
#       dtype='<U8'),
#        array(['where', 'to', 'find', 'morel', 'mushrooms'], dtype='<U9'),
#        array(['im', 'looking', 'for', 'information', 'on', 'common',
#        'schizophrenia', 'drugs'], dtype='<U13'),
#        array(['im', 'looking', 'for', 'information', 'on', 'recycling', 'lead',
#        'acid', 'batteries'], dtype='<U11'),
#        array(['where', 'can', 'i', 'find', 'cheap', 'internet'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'madam', 'cj', 'walker'], dtype='<U6'),
#        array(['child', 'support', 'in', 'indiana'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'the', 'sit', 'and', 'reach', 'test'],
#       dtype='<U5'),
#        array(['what', 'are', 'characteristics', 'of', 'uranus'], dtype='<U15'),
#        array(['tell', 'me', 'about', 'electronic', 'skeet', 'shoot'],
#       dtype='<U10'),
#        array(['how', 'can', 'one', 'can', 'become', 'highway', 'patrol'],
#       dtype='<U7'),
#        array(['what', 'is', 'a', '403b'], dtype='<U4'),
#        array(['find', 'me', 'information', 'about', 'the', 'last', 'supper',
#        'painting'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'on', 'the', 'beatles',
#        'rock', 'band'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'furniture', 'for', 'small', 'spaces'],
#       dtype='<U9'),
#        array(['im', 'interested', 'in', 'poker', 'tournaments'], dtype='<U11'),
#        array(['tell', 'me', 'about', 'scooters'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'ron', 'howard'], dtype='<U6'),
#        array(['im', 'looking', 'for', 'information', 'on', 'becoming', 'a',
#        'paralegal'], dtype='<U11'),
#        array(['how', 'to', 'cook', 'pork', 'tenderlion'], dtype='<U10'),
#        array(['i', '’', 'm', 'interested', 'in', 'old', 'coins'], dtype='<U10'),
#        array(['how', 'can', 'i', 'quick', 'smoking'], dtype='<U7'),
#        array(['i', '’', 'm', 'interested', 'in', 'civil', 'right', 'movement'],
#       dtype='<U10'),
#        array(['find', 'condos', 'in', 'florida'], dtype='<U7'),
#        array(['tell', 'me', 'about', 'designer', 'dog', 'breeds'], dtype='<U8'),
#        array(['looking', 'for', 'information', 'about', 'the', 'orange',
#        'county', 'convention', 'center'], dtype='<U11'),
#        array(['tell', 'me', 'more', 'about', 'usa', 'tax', 'for', 'annuity'],
#       dtype='<U7'),
#        array(['tell', 'me', 'about', 'texas', 'border', 'patrol'], dtype='<U6'),
#        array(['id', 'like', 'to', 'learn', 'about', 'moths'], dtype='<U5'),
#        array(['give', 'me', 'air', 'travel', 'information'], dtype='<U11'),
#        array(['find', 'information', 'on', 'raised', 'gardens'], dtype='<U11'),
#        array(['im', 'looking', 'for', 'information', 'on', 'dieting'],
#       dtype='<U11'),
#        array(['tell', 'me', 'about', 'bart', 'sf'], dtype='<U5'),
#        array(['who', 'invented', 'music'], dtype='<U8'),
#        array(['tell', 'me', 'about', 'er', 'television', 'show'], dtype='<U10'),
#        array(['find', 'information', 'about', 'the', 'wall'], dtype='<U11'),
#        array(['give', 'me', 'information', 'about', 'titan'], dtype='<U11'),
#        array(['find', 'me', 'reviews', 'of', 'the', 'les', 'miserables'],
#       dtype='<U10'),
#        array(['tell', 'me', 'about', 'dark', 'chocolate', 'health', 'benefits'],
#       dtype='<U9'),
#        array(['tell', 'me', 'bio', 'of', 'george', 'bush', 'sr'], dtype='<U6'),
#        array(['tell', 'me', 'more', 'about', 'us', 'presidents'], dtype='<U10'),
#        array(['tell', 'me', 'about', 'folk', 'remedies', 'for', 'a', 'sore',
#        'throat'], dtype='<U8'),
#        array(['how', 'do', 'you', 'tie', 'a', 'windsor', 'knot'], dtype='<U7')],
#       dtype=object)

# %%
inputs_aug = []
labels_aug = []
for i in tqdm(range(len(inputs))):
    perms = list(multiset_permutations(inputs[i]))[:5]
    for p in perms:
        inputs_aug.append(np.array(p, dtype = np.str))
        labels_aug.append(labels[i])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=187.0), HTML(value='')))

# %%
inputs_aug
# Out:
# [array(['about', 'family', 'me', 'obama', 'tell', 'tree'], dtype='<U6'),
#  array(['about', 'family', 'me', 'obama', 'tree', 'tell'], dtype='<U6'),
#  array(['about', 'family', 'me', 'tell', 'obama', 'tree'], dtype='<U6'),
#  array(['about', 'family', 'me', 'tell', 'tree', 'obama'], dtype='<U6'),
#  array(['about', 'family', 'me', 'tree', 'obama', 'tell'], dtype='<U6'),
#  array(['creek', 'farm', 'fickle', 'is', 'what'], dtype='<U6'),
#  array(['creek', 'farm', 'fickle', 'what', 'is'], dtype='<U6'),
#  array(['creek', 'farm', 'is', 'fickle', 'what'], dtype='<U6'),
#  array(['creek', 'farm', 'is', 'what', 'fickle'], dtype='<U6'),
#  array(['creek', 'farm', 'what', 'fickle', 'is'], dtype='<U6'),
#  array(['about', 'county', 'me', 'medical', 'services', 'sonoma', 'tell'],
#        dtype='<U8'),
#  array(['about', 'county', 'me', 'medical', 'services', 'tell', 'sonoma'],
#        dtype='<U8'),
#  array(['about', 'county', 'me', 'medical', 'sonoma', 'services', 'tell'],
#        dtype='<U8'),
#  array(['about', 'county', 'me', 'medical', 'sonoma', 'tell', 'services'],
#        dtype='<U8'),
#  array(['about', 'county', 'me', 'medical', 'tell', 'services', 'sonoma'],
#        dtype='<U8'),
#  array(['about', 'brester', 'me', 'of', 'owen', 'ralph', 'tell'],
#        dtype='<U7'),
#  array(['about', 'brester', 'me', 'of', 'owen', 'tell', 'ralph'],
#        dtype='<U7'),
#  array(['about', 'brester', 'me', 'of', 'ralph', 'owen', 'tell'],
#        dtype='<U7'),
#  array(['about', 'brester', 'me', 'of', 'ralph', 'tell', 'owen'],
#        dtype='<U7'),
#  array(['about', 'brester', 'me', 'of', 'tell', 'owen', 'ralph'],
#        dtype='<U7'),
#  array(['about', 'clinic', 'fl', 'for', 'im', 'information',
#         'jacksonville', 'looking', 'mayo'], dtype='<U12'),
#  array(['about', 'clinic', 'fl', 'for', 'im', 'information',
#         'jacksonville', 'mayo', 'looking'], dtype='<U12'),
#  array(['about', 'clinic', 'fl', 'for', 'im', 'information', 'looking',
#         'jacksonville', 'mayo'], dtype='<U12'),
#  array(['about', 'clinic', 'fl', 'for', 'im', 'information', 'looking',
#         'mayo', 'jacksonville'], dtype='<U12'),
#  array(['about', 'clinic', 'fl', 'for', 'im', 'information', 'mayo',
#         'jacksonville', 'looking'], dtype='<U12'),
#  array(['for', 'gmat', 'how', 'prepare', 'the', 'to'], dtype='<U7'),
#  array(['for', 'gmat', 'how', 'prepare', 'to', 'the'], dtype='<U7'),
#  array(['for', 'gmat', 'how', 'the', 'prepare', 'to'], dtype='<U7'),
#  array(['for', 'gmat', 'how', 'the', 'to', 'prepare'], dtype='<U7'),
#  array(['for', 'gmat', 'how', 'to', 'prepare', 'the'], dtype='<U7'),
#  array(['about', 'dogs', 'id', 'in', 'learn', 'like', 'lymphoma', 'to'],
#        dtype='<U8'),
#  array(['about', 'dogs', 'id', 'in', 'learn', 'like', 'to', 'lymphoma'],
#        dtype='<U8'),
#  array(['about', 'dogs', 'id', 'in', 'learn', 'lymphoma', 'like', 'to'],
#        dtype='<U8'),
#  array(['about', 'dogs', 'id', 'in', 'learn', 'lymphoma', 'to', 'like'],
#        dtype='<U8'),
#  array(['about', 'dogs', 'id', 'in', 'learn', 'to', 'like', 'lymphoma'],
#        dtype='<U8'),
#  array(['good', 'heater', 'is', 'kenmore'], dtype='<U7'),
#  array(['good', 'heater', 'kenmore', 'is'], dtype='<U7'),
#  array(['good', 'is', 'heater', 'kenmore'], dtype='<U7'),
#  array(['good', 'is', 'kenmore', 'heater'], dtype='<U7'),
#  array(['good', 'kenmore', 'heater', 'is'], dtype='<U7'),
#  array(['2140', 'about', 'hp', 'me', 'mini', 'more', 'tell'], dtype='<U5'),
#  array(['2140', 'about', 'hp', 'me', 'mini', 'tell', 'more'], dtype='<U5'),
#  array(['2140', 'about', 'hp', 'me', 'more', 'mini', 'tell'], dtype='<U5'),
#  array(['2140', 'about', 'hp', 'me', 'more', 'tell', 'mini'], dtype='<U5'),
#  array(['2140', 'about', 'hp', 'me', 'tell', 'mini', 'more'], dtype='<U5'),
#  array(['about', 'laboratory', 'me', 'northwest', 'pacific', 'tell', 'the'],
#        dtype='<U10'),
#  array(['about', 'laboratory', 'me', 'northwest', 'pacific', 'the', 'tell'],
#        dtype='<U10'),
#  array(['about', 'laboratory', 'me', 'northwest', 'tell', 'pacific', 'the'],
#        dtype='<U10'),
#  array(['about', 'laboratory', 'me', 'northwest', 'tell', 'the', 'pacific'],
#        dtype='<U10'),
#  array(['about', 'laboratory', 'me', 'northwest', 'the', 'pacific', 'tell'],
#        dtype='<U10'),
#  array(['board', 'california', 'franchise', 'is', 'tax', 'what'],
#        dtype='<U10'),
#  array(['board', 'california', 'franchise', 'is', 'what', 'tax'],
#        dtype='<U10'),
#  array(['board', 'california', 'franchise', 'tax', 'is', 'what'],
#        dtype='<U10'),
#  array(['board', 'california', 'franchise', 'tax', 'what', 'is'],
#        dtype='<U10'),
#  array(['board', 'california', 'franchise', 'what', 'is', 'tax'],
#        dtype='<U10'),
#  array(['are', 'asbestos', 'dangers', 'of', 'specific', 'what'],
#        dtype='<U8'),
#  array(['are', 'asbestos', 'dangers', 'of', 'what', 'specific'],
#        dtype='<U8'),
#  array(['are', 'asbestos', 'dangers', 'specific', 'of', 'what'],
#        dtype='<U8'),
#  array(['are', 'asbestos', 'dangers', 'specific', 'what', 'of'],
#        dtype='<U8'),
#  array(['are', 'asbestos', 'dangers', 'what', 'of', 'specific'],
#        dtype='<U8'),
#  array(['a', 'after', 'an', 'how', 'interview', 'letter', 'thank', 'to',
#         'write', 'you'], dtype='<U9'),
#  array(['a', 'after', 'an', 'how', 'interview', 'letter', 'thank', 'to',
#         'you', 'write'], dtype='<U9'),
#  array(['a', 'after', 'an', 'how', 'interview', 'letter', 'thank', 'write',
#         'to', 'you'], dtype='<U9'),
#  array(['a', 'after', 'an', 'how', 'interview', 'letter', 'thank', 'write',
#         'you', 'to'], dtype='<U9'),
#  array(['a', 'after', 'an', 'how', 'interview', 'letter', 'thank', 'you',
#         'to', 'write'], dtype='<U9'),
#  array(['disc', 'hire', 'how', 'jockey', 'to'], dtype='<U6'),
#  array(['disc', 'hire', 'how', 'to', 'jockey'], dtype='<U6'),
#  array(['disc', 'hire', 'jockey', 'how', 'to'], dtype='<U6'),
#  array(['disc', 'hire', 'jockey', 'to', 'how'], dtype='<U6'),
#  array(['disc', 'hire', 'to', 'how', 'jockey'], dtype='<U6'),
#  array(['computer', 'on', 'tv'], dtype='<U8'),
#  array(['computer', 'tv', 'on'], dtype='<U8'),
#  array(['on', 'computer', 'tv'], dtype='<U8'),
#  array(['on', 'tv', 'computer'], dtype='<U8'),
#  array(['tv', 'computer', 'on'], dtype='<U8'),
#  array(['about', 'cemetry', 'culpeper', 'me', 'more', 'national', 'tell'],
#        dtype='<U8'),
#  array(['about', 'cemetry', 'culpeper', 'me', 'more', 'tell', 'national'],
#        dtype='<U8'),
#  array(['about', 'cemetry', 'culpeper', 'me', 'national', 'more', 'tell'],
#        dtype='<U8'),
#  array(['about', 'cemetry', 'culpeper', 'me', 'national', 'tell', 'more'],
#        dtype='<U8'),
#  array(['about', 'cemetry', 'culpeper', 'me', 'tell', 'more', 'national'],
#        dtype='<U8'),
#  array(['about', 'bowflex', 'me', 'power', 'pro', 'tell'], dtype='<U7'),
#  array(['about', 'bowflex', 'me', 'power', 'tell', 'pro'], dtype='<U7'),
#  array(['about', 'bowflex', 'me', 'pro', 'power', 'tell'], dtype='<U7'),
#  array(['about', 'bowflex', 'me', 'pro', 'tell', 'power'], dtype='<U7'),
#  array(['about', 'bowflex', 'me', 'tell', 'power', 'pro'], dtype='<U7'),
#  array(['and', 'butter', 'margarine'], dtype='<U9'),
#  array(['and', 'margarine', 'butter'], dtype='<U9'),
#  array(['butter', 'and', 'margarine'], dtype='<U9'),
#  array(['butter', 'margarine', 'and'], dtype='<U9'),
#  array(['margarine', 'and', 'butter'], dtype='<U9'),
#  array(['county', 'duchess', 'for', 'im', 'information', 'looking', 'on',
#         'tourism'], dtype='<U11'),
#  array(['county', 'duchess', 'for', 'im', 'information', 'looking',
#         'tourism', 'on'], dtype='<U11'),
#  array(['county', 'duchess', 'for', 'im', 'information', 'on', 'looking',
#         'tourism'], dtype='<U11'),
#  array(['county', 'duchess', 'for', 'im', 'information', 'on', 'tourism',
#         'looking'], dtype='<U11'),
#  array(['county', 'duchess', 'for', 'im', 'information', 'tourism',
#         'looking', 'on'], dtype='<U11'),
#  array(['about', 'food', 'information', 'iowas', 'me', 'program', 'stamp',
#         'tell'], dtype='<U11'),
#  array(['about', 'food', 'information', 'iowas', 'me', 'program', 'tell',
#         'stamp'], dtype='<U11'),
#  array(['about', 'food', 'information', 'iowas', 'me', 'stamp', 'program',
#         'tell'], dtype='<U11'),
#  array(['about', 'food', 'information', 'iowas', 'me', 'stamp', 'tell',
#         'program'], dtype='<U11'),
#  array(['about', 'food', 'information', 'iowas', 'me', 'tell', 'program',
#         'stamp'], dtype='<U11'),
#  array(['map'], dtype='<U3'),
#  array(['employer', 'equal', 'is', 'opportunity', 'what'], dtype='<U11'),
#  array(['employer', 'equal', 'is', 'what', 'opportunity'], dtype='<U11'),
#  array(['employer', 'equal', 'opportunity', 'is', 'what'], dtype='<U11'),
#  array(['employer', 'equal', 'opportunity', 'what', 'is'], dtype='<U11'),
#  array(['employer', 'equal', 'what', 'is', 'opportunity'], dtype='<U11'),
#  array(['day', 'im', 'in', 'interested', 'mothers', 'songs'], dtype='<U10'),
#  array(['day', 'im', 'in', 'interested', 'songs', 'mothers'], dtype='<U10'),
#  array(['day', 'im', 'in', 'mothers', 'interested', 'songs'], dtype='<U10'),
#  array(['day', 'im', 'in', 'mothers', 'songs', 'interested'], dtype='<U10'),
#  array(['day', 'im', 'in', 'songs', 'interested', 'mothers'], dtype='<U10'),
#  array(['about', 'me', 'nile', 'of', 'source', 'tell', 'the'], dtype='<U6'),
#  array(['about', 'me', 'nile', 'of', 'source', 'the', 'tell'], dtype='<U6'),
#  array(['about', 'me', 'nile', 'of', 'tell', 'source', 'the'], dtype='<U6'),
#  array(['about', 'me', 'nile', 'of', 'tell', 'the', 'source'], dtype='<U6'),
#  array(['about', 'me', 'nile', 'of', 'the', 'source', 'tell'], dtype='<U6'),
#  array(['about', 'american', 'me', 'military', 'tell', 'university'],
#        dtype='<U10'),
#  array(['about', 'american', 'me', 'military', 'university', 'tell'],
#        dtype='<U10'),
#  array(['about', 'american', 'me', 'tell', 'military', 'university'],
#        dtype='<U10'),
#  array(['about', 'american', 'me', 'tell', 'university', 'military'],
#        dtype='<U10'),
#  array(['about', 'american', 'me', 'university', 'military', 'tell'],
#        dtype='<U10'),
#  array(['about', 'and', 'gem', 'me', 'rock', 'shows', 'tell'], dtype='<U5'),
#  array(['about', 'and', 'gem', 'me', 'rock', 'tell', 'shows'], dtype='<U5'),
#  array(['about', 'and', 'gem', 'me', 'shows', 'rock', 'tell'], dtype='<U5'),
#  array(['about', 'and', 'gem', 'me', 'shows', 'tell', 'rock'], dtype='<U5'),
#  array(['about', 'and', 'gem', 'me', 'tell', 'rock', 'shows'], dtype='<U5'),
#  array(['chemical', 'company', 'for', 'im', 'information', 'jax',
#         'looking', 'on'], dtype='<U11'),
#  array(['chemical', 'company', 'for', 'im', 'information', 'jax', 'on',
#         'looking'], dtype='<U11'),
#  array(['chemical', 'company', 'for', 'im', 'information', 'looking',
#         'jax', 'on'], dtype='<U11'),
#  array(['chemical', 'company', 'for', 'im', 'information', 'looking', 'on',
#         'jax'], dtype='<U11'),
#  array(['chemical', 'company', 'for', 'im', 'information', 'on', 'jax',
#         'looking'], dtype='<U11'),
#  array(['dinosaurs', 'im', 'in', 'interested'], dtype='<U10'),
#  array(['dinosaurs', 'im', 'interested', 'in'], dtype='<U10'),
#  array(['dinosaurs', 'in', 'im', 'interested'], dtype='<U10'),
#  array(['dinosaurs', 'in', 'interested', 'im'], dtype='<U10'),
#  array(['dinosaurs', 'interested', 'im', 'in'], dtype='<U10'),
#  array(['about', 'east', 'high', 'information', 'ridge', 'school'],
#        dtype='<U11'),
#  array(['about', 'east', 'high', 'information', 'school', 'ridge'],
#        dtype='<U11'),
#  array(['about', 'east', 'high', 'ridge', 'information', 'school'],
#        dtype='<U11'),
#  array(['about', 'east', 'high', 'ridge', 'school', 'information'],
#        dtype='<U11'),
#  array(['about', 'east', 'high', 'school', 'information', 'ridge'],
#        dtype='<U11'),
#  array(['dmv', 'how', 'in', 'register', 'to', 'va'], dtype='<U8'),
#  array(['dmv', 'how', 'in', 'register', 'va', 'to'], dtype='<U8'),
#  array(['dmv', 'how', 'in', 'to', 'register', 'va'], dtype='<U8'),
#  array(['dmv', 'how', 'in', 'to', 'va', 'register'], dtype='<U8'),
#  array(['dmv', 'how', 'in', 'va', 'register', 'to'], dtype='<U8'),
#  array(['arkansas', 'clubs', 'health', 'in', 'me', 'more', 'on', 'tell'],
#        dtype='<U8'),
#  array(['arkansas', 'clubs', 'health', 'in', 'me', 'more', 'tell', 'on'],
#        dtype='<U8'),
#  array(['arkansas', 'clubs', 'health', 'in', 'me', 'on', 'more', 'tell'],
#        dtype='<U8'),
#  array(['arkansas', 'clubs', 'health', 'in', 'me', 'on', 'tell', 'more'],
#        dtype='<U8'),
#  array(['arkansas', 'clubs', 'health', 'in', 'me', 'tell', 'more', 'on'],
#        dtype='<U8'),
#  array(['a', 'buy', 'can', 'i', 'trombone', 'where'], dtype='<U8'),
#  array(['a', 'buy', 'can', 'i', 'where', 'trombone'], dtype='<U8'),
#  array(['a', 'buy', 'can', 'trombone', 'i', 'where'], dtype='<U8'),
#  array(['a', 'buy', 'can', 'trombone', 'where', 'i'], dtype='<U8'),
#  array(['a', 'buy', 'can', 'where', 'i', 'trombone'], dtype='<U8'),
#  array(['about', 'for', 'me', 'shade', 'tell', 'vines'], dtype='<U5'),
#  array(['about', 'for', 'me', 'shade', 'vines', 'tell'], dtype='<U5'),
#  array(['about', 'for', 'me', 'tell', 'shade', 'vines'], dtype='<U5'),
#  array(['about', 'for', 'me', 'tell', 'vines', 'shade'], dtype='<U5'),
#  array(['about', 'for', 'me', 'vines', 'shade', 'tell'], dtype='<U5'),
#  array(['can', 'do', 'i', 'in', 'library', 'regional', 'sherwood', 'what'],
#        dtype='<U8'),
#  array(['can', 'do', 'i', 'in', 'library', 'regional', 'what', 'sherwood'],
#        dtype='<U8'),
#  array(['can', 'do', 'i', 'in', 'library', 'sherwood', 'regional', 'what'],
#        dtype='<U8'),
#  array(['can', 'do', 'i', 'in', 'library', 'sherwood', 'what', 'regional'],
#        dtype='<U8'),
#  array(['can', 'do', 'i', 'in', 'library', 'what', 'regional', 'sherwood'],
#        dtype='<U8'),
#  array(['about', 'me', 'personal', 'property', 'tangible', 'tax', 'tell'],
#        dtype='<U8'),
#  array(['about', 'me', 'personal', 'property', 'tangible', 'tell', 'tax'],
#        dtype='<U8'),
#  array(['about', 'me', 'personal', 'property', 'tax', 'tangible', 'tell'],
#        dtype='<U8'),
#  array(['about', 'me', 'personal', 'property', 'tax', 'tell', 'tangible'],
#        dtype='<U8'),
#  array(['about', 'me', 'personal', 'property', 'tell', 'tangible', 'tax'],
#        dtype='<U8'),
#  array(['and', 'imclone', 'is', 'martha', 'stewart', 'what'], dtype='<U7'),
#  array(['and', 'imclone', 'is', 'martha', 'what', 'stewart'], dtype='<U7'),
#  array(['and', 'imclone', 'is', 'stewart', 'martha', 'what'], dtype='<U7'),
#  array(['and', 'imclone', 'is', 'stewart', 'what', 'martha'], dtype='<U7'),
#  array(['and', 'imclone', 'is', 'what', 'martha', 'stewart'], dtype='<U7'),
#  array(['about', 'at', 'me', 'national', 'park', 'tell', 'uplift',
#         'yellowstone'], dtype='<U11'),
#  array(['about', 'at', 'me', 'national', 'park', 'tell', 'yellowstone',
#         'uplift'], dtype='<U11'),
#  array(['about', 'at', 'me', 'national', 'park', 'uplift', 'tell',
#         'yellowstone'], dtype='<U11'),
#  array(['about', 'at', 'me', 'national', 'park', 'uplift', 'yellowstone',
#         'tell'], dtype='<U11'),
#  array(['about', 'at', 'me', 'national', 'park', 'yellowstone', 'tell',
#         'uplift'], dtype='<U11'),
#  array(['espn', 'give', 'information', 'me', 'sports'], dtype='<U11'),
#  array(['espn', 'give', 'information', 'sports', 'me'], dtype='<U11'),
#  array(['espn', 'give', 'me', 'information', 'sports'], dtype='<U11'),
#  array(['espn', 'give', 'me', 'sports', 'information'], dtype='<U11'),
#  array(['espn', 'give', 'sports', 'information', 'me'], dtype='<U11'),
#  array(['about', 'me', 'pocono', 'tell'], dtype='<U6'),
#  array(['about', 'me', 'tell', 'pocono'], dtype='<U6'),
#  array(['about', 'pocono', 'me', 'tell'], dtype='<U6'),
#  array(['about', 'pocono', 'tell', 'me'], dtype='<U6'),
#  array(['about', 'tell', 'me', 'pocono'], dtype='<U6'),
#  array(['figs'], dtype='<U4'),
#  array(['about', 'i', 'information', 'need', 'of', 'phoenix', 'the',
#         'university'], dtype='<U11'),
#  array(['about', 'i', 'information', 'need', 'of', 'phoenix', 'university',
#         'the'], dtype='<U11'),
#  array(['about', 'i', 'information', 'need', 'of', 'the', 'phoenix',
#         'university'], dtype='<U11'),
#  array(['about', 'i', 'information', 'need', 'of', 'the', 'university',
#         'phoenix'], dtype='<U11'),
#  array(['about', 'i', 'information', 'need', 'of', 'university', 'phoenix',
#         'the'], dtype='<U11'),
#  array(['design', 'how', 'i', 'septic', 'should', 'system', 'the', 'use'],
#        dtype='<U6'),
#  array(['design', 'how', 'i', 'septic', 'should', 'system', 'use', 'the'],
#        dtype='<U6'),
#  array(['design', 'how', 'i', 'septic', 'should', 'the', 'system', 'use'],
#        dtype='<U6'),
#  array(['design', 'how', 'i', 'septic', 'should', 'the', 'use', 'system'],
#        dtype='<U6'),
#  array(['design', 'how', 'i', 'septic', 'should', 'use', 'system', 'the'],
#        dtype='<U6'),
#  array(['find', 'information', 'on', 'porterville'], dtype='<U11'),
#  array(['find', 'information', 'porterville', 'on'], dtype='<U11'),
#  array(['find', 'on', 'information', 'porterville'], dtype='<U11'),
#  array(['find', 'on', 'porterville', 'information'], dtype='<U11'),
#  array(['find', 'porterville', 'information', 'on'], dtype='<U11'),
#  array(['about', 'and', 'arizona', 'fish', 'for', 'game', 'im', 'in',
#         'information', 'looking'], dtype='<U11'),
#  array(['about', 'and', 'arizona', 'fish', 'for', 'game', 'im', 'in',
#         'looking', 'information'], dtype='<U11'),
#  array(['about', 'and', 'arizona', 'fish', 'for', 'game', 'im',
#         'information', 'in', 'looking'], dtype='<U11'),
#  array(['about', 'and', 'arizona', 'fish', 'for', 'game', 'im',
#         'information', 'looking', 'in'], dtype='<U11'),
#  array(['about', 'and', 'arizona', 'fish', 'for', 'game', 'im', 'looking',
#         'in', 'information'], dtype='<U11'),
#  array(['are', 'best', 'for', 'grilling', 'recepies', 'the', 'what'],
#        dtype='<U8'),
#  array(['are', 'best', 'for', 'grilling', 'recepies', 'what', 'the'],
#        dtype='<U8'),
#  array(['are', 'best', 'for', 'grilling', 'the', 'recepies', 'what'],
#        dtype='<U8'),
#  array(['are', 'best', 'for', 'grilling', 'the', 'what', 'recepies'],
#        dtype='<U8'),
#  array(['are', 'best', 'for', 'grilling', 'what', 'recepies', 'the'],
#        dtype='<U8'),
#  array(['about', 'dnr', 'me', 'more', 'tell'], dtype='<U5'),
#  array(['about', 'dnr', 'me', 'tell', 'more'], dtype='<U5'),
#  array(['about', 'dnr', 'more', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'dnr', 'more', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'dnr', 'tell', 'me', 'more'], dtype='<U5'),
#  array(['arkansas', 'do', 'in', 'to', 'what'], dtype='<U8'),
#  array(['arkansas', 'do', 'in', 'what', 'to'], dtype='<U8'),
#  array(['arkansas', 'do', 'to', 'in', 'what'], dtype='<U8'),
#  array(['arkansas', 'do', 'to', 'what', 'in'], dtype='<U8'),
#  array(['arkansas', 'do', 'what', 'in', 'to'], dtype='<U8'),
#  array(['about', 'barbados', 'me', 'tell'], dtype='<U8'),
#  array(['about', 'barbados', 'tell', 'me'], dtype='<U8'),
#  array(['about', 'me', 'barbados', 'tell'], dtype='<U8'),
#  array(['about', 'me', 'tell', 'barbados'], dtype='<U8'),
#  array(['about', 'tell', 'barbados', 'me'], dtype='<U8'),
#  array(['are', 'causes', 'lipoma', 'of', 'the', 'tumors', 'what'],
#        dtype='<U6'),
#  array(['are', 'causes', 'lipoma', 'of', 'the', 'what', 'tumors'],
#        dtype='<U6'),
#  array(['are', 'causes', 'lipoma', 'of', 'tumors', 'the', 'what'],
#        dtype='<U6'),
#  array(['are', 'causes', 'lipoma', 'of', 'tumors', 'what', 'the'],
#        dtype='<U6'),
#  array(['are', 'causes', 'lipoma', 'of', 'what', 'the', 'tumors'],
#        dtype='<U6'),
#  array(['find', 'fractures', 'hip', 'information', 'on'], dtype='<U11'),
#  array(['find', 'fractures', 'hip', 'on', 'information'], dtype='<U11'),
#  array(['find', 'fractures', 'information', 'hip', 'on'], dtype='<U11'),
#  array(['find', 'fractures', 'information', 'on', 'hip'], dtype='<U11'),
#  array(['find', 'fractures', 'on', 'hip', 'information'], dtype='<U11'),
#  array(['a', 'are', 'heartattack', 'of', 'signs', 'what'], dtype='<U11'),
#  array(['a', 'are', 'heartattack', 'of', 'what', 'signs'], dtype='<U11'),
#  array(['a', 'are', 'heartattack', 'signs', 'of', 'what'], dtype='<U11'),
#  array(['a', 'are', 'heartattack', 'signs', 'what', 'of'], dtype='<U11'),
#  array(['a', 'are', 'heartattack', 'what', 'of', 'signs'], dtype='<U11'),
#  array(['about', 'me', 'stripping', 'tell', 'weather'], dtype='<U9'),
#  array(['about', 'me', 'stripping', 'weather', 'tell'], dtype='<U9'),
#  array(['about', 'me', 'tell', 'stripping', 'weather'], dtype='<U9'),
#  array(['about', 'me', 'tell', 'weather', 'stripping'], dtype='<U9'),
#  array(['about', 'me', 'weather', 'stripping', 'tell'], dtype='<U9'),
#  array(['best', 'care', 'insurance', 'is', 'long', 'term', 'the', 'what'],
#        dtype='<U9'),
#  array(['best', 'care', 'insurance', 'is', 'long', 'term', 'what', 'the'],
#        dtype='<U9'),
#  array(['best', 'care', 'insurance', 'is', 'long', 'the', 'term', 'what'],
#        dtype='<U9'),
#  array(['best', 'care', 'insurance', 'is', 'long', 'the', 'what', 'term'],
#        dtype='<U9'),
#  array(['best', 'care', 'insurance', 'is', 'long', 'what', 'term', 'the'],
#        dtype='<U9'),
#  array(['about', 'black', 'history', 'me', 'tell'], dtype='<U7'),
#  array(['about', 'black', 'history', 'tell', 'me'], dtype='<U7'),
#  array(['about', 'black', 'me', 'history', 'tell'], dtype='<U7'),
#  array(['about', 'black', 'me', 'tell', 'history'], dtype='<U7'),
#  array(['about', 'black', 'tell', 'history', 'me'], dtype='<U7'),
#  array(['about', 'hotels', 'in', 'me', 'new', 'tell', 'york'], dtype='<U6'),
#  array(['about', 'hotels', 'in', 'me', 'new', 'york', 'tell'], dtype='<U6'),
#  array(['about', 'hotels', 'in', 'me', 'tell', 'new', 'york'], dtype='<U6'),
#  array(['about', 'hotels', 'in', 'me', 'tell', 'york', 'new'], dtype='<U6'),
#  array(['about', 'hotels', 'in', 'me', 'york', 'new', 'tell'], dtype='<U6'),
#  array(['about', 'city', 'kansas', 'me', 'mo', 'tell'], dtype='<U6'),
#  array(['about', 'city', 'kansas', 'me', 'tell', 'mo'], dtype='<U6'),
#  array(['about', 'city', 'kansas', 'mo', 'me', 'tell'], dtype='<U6'),
#  array(['about', 'city', 'kansas', 'mo', 'tell', 'me'], dtype='<U6'),
#  array(['about', 'city', 'kansas', 'tell', 'me', 'mo'], dtype='<U6'),
#  array(['annual', 'credit', 'do', 'free', 'get', 'how', 'i', 'my',
#         'report'], dtype='<U6'),
#  array(['annual', 'credit', 'do', 'free', 'get', 'how', 'i', 'report',
#         'my'], dtype='<U6'),
#  array(['annual', 'credit', 'do', 'free', 'get', 'how', 'my', 'i',
#         'report'], dtype='<U6'),
#  array(['annual', 'credit', 'do', 'free', 'get', 'how', 'my', 'report',
#         'i'], dtype='<U6'),
#  array(['annual', 'credit', 'do', 'free', 'get', 'how', 'report', 'i',
#         'my'], dtype='<U6'),
#  array(['about', 'me', 'tell', 'unc'], dtype='<U5'),
#  array(['about', 'me', 'unc', 'tell'], dtype='<U5'),
#  array(['about', 'tell', 'me', 'unc'], dtype='<U5'),
#  array(['about', 'tell', 'unc', 'me'], dtype='<U5'),
#  array(['about', 'unc', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'vanuatu'], dtype='<U7'),
#  array(['about', 'me', 'vanuatu', 'tell'], dtype='<U7'),
#  array(['about', 'tell', 'me', 'vanuatu'], dtype='<U7'),
#  array(['about', 'tell', 'vanuatu', 'me'], dtype='<U7'),
#  array(['about', 'vanuatu', 'me', 'tell'], dtype='<U7'),
#  array(['about', 'internet', 'me', 'phone', 'serices', 'tell'], dtype='<U8'),
#  array(['about', 'internet', 'me', 'phone', 'tell', 'serices'], dtype='<U8'),
#  array(['about', 'internet', 'me', 'serices', 'phone', 'tell'], dtype='<U8'),
#  array(['about', 'internet', 'me', 'serices', 'tell', 'phone'], dtype='<U8'),
#  array(['about', 'internet', 'me', 'tell', 'phone', 'serices'], dtype='<U8'),
#  array(['about', 'find', 'gs', 'information', 'pay', 'rate', 'the'],
#        dtype='<U11'),
#  array(['about', 'find', 'gs', 'information', 'pay', 'the', 'rate'],
#        dtype='<U11'),
#  array(['about', 'find', 'gs', 'information', 'rate', 'pay', 'the'],
#        dtype='<U11'),
#  array(['about', 'find', 'gs', 'information', 'rate', 'the', 'pay'],
#        dtype='<U11'),
#  array(['about', 'find', 'gs', 'information', 'the', 'pay', 'rate'],
#        dtype='<U11'),
#  array(['current', 'me', 'take', 'the', 'to'], dtype='<U7'),
#  array(['current', 'me', 'take', 'to', 'the'], dtype='<U7'),
#  array(['current', 'me', 'the', 'take', 'to'], dtype='<U7'),
#  array(['current', 'me', 'the', 'to', 'take'], dtype='<U7'),
#  array(['current', 'me', 'to', 'take', 'the'], dtype='<U7'),
#  array(['a', 'about', 'information', 'me', 'sore', 'tell', 'throat'],
#        dtype='<U11'),
#  array(['a', 'about', 'information', 'me', 'sore', 'throat', 'tell'],
#        dtype='<U11'),
#  array(['a', 'about', 'information', 'me', 'tell', 'sore', 'throat'],
#        dtype='<U11'),
#  array(['a', 'about', 'information', 'me', 'tell', 'throat', 'sore'],
#        dtype='<U11'),
#  array(['a', 'about', 'information', 'me', 'throat', 'sore', 'tell'],
#        dtype='<U11'),
#  array(['about', 'flower', 'idaho', 'me', 'state', 'tell'], dtype='<U6'),
#  array(['about', 'flower', 'idaho', 'me', 'tell', 'state'], dtype='<U6'),
#  array(['about', 'flower', 'idaho', 'state', 'me', 'tell'], dtype='<U6'),
#  array(['about', 'flower', 'idaho', 'state', 'tell', 'me'], dtype='<U6'),
#  array(['about', 'flower', 'idaho', 'tell', 'me', 'state'], dtype='<U6'),
#  array(['about', 'fairgrounds', 'indiana', 'me', 'more', 'state', 'tell'],
#        dtype='<U11'),
#  array(['about', 'fairgrounds', 'indiana', 'me', 'more', 'tell', 'state'],
#        dtype='<U11'),
#  array(['about', 'fairgrounds', 'indiana', 'me', 'state', 'more', 'tell'],
#        dtype='<U11'),
#  array(['about', 'fairgrounds', 'indiana', 'me', 'state', 'tell', 'more'],
#        dtype='<U11'),
#  array(['about', 'fairgrounds', 'indiana', 'me', 'tell', 'more', 'state'],
#        dtype='<U11'),
#  array(['about', 'fybromyalgia', 'me', 'tell'], dtype='<U12'),
#  array(['about', 'fybromyalgia', 'tell', 'me'], dtype='<U12'),
#  array(['about', 'me', 'fybromyalgia', 'tell'], dtype='<U12'),
#  array(['about', 'me', 'tell', 'fybromyalgia'], dtype='<U12'),
#  array(['about', 'tell', 'fybromyalgia', 'me'], dtype='<U12'),
#  array(['and', 'casino', 'find', 'french', 'information', 'lick', 'on',
#         'resort'], dtype='<U11'),
#  array(['and', 'casino', 'find', 'french', 'information', 'lick', 'resort',
#         'on'], dtype='<U11'),
#  array(['and', 'casino', 'find', 'french', 'information', 'on', 'lick',
#         'resort'], dtype='<U11'),
#  array(['and', 'casino', 'find', 'french', 'information', 'on', 'resort',
#         'lick'], dtype='<U11'),
#  array(['and', 'casino', 'find', 'french', 'information', 'resort', 'lick',
#         'on'], dtype='<U11'),
#  array(['about', 'information', 'me', 'tell', 'volvo'], dtype='<U11'),
#  array(['about', 'information', 'me', 'volvo', 'tell'], dtype='<U11'),
#  array(['about', 'information', 'tell', 'me', 'volvo'], dtype='<U11'),
#  array(['about', 'information', 'tell', 'volvo', 'me'], dtype='<U11'),
#  array(['about', 'information', 'volvo', 'me', 'tell'], dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'on', 'rick', 'warren'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'on', 'warren', 'rick'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'rick', 'on', 'warren'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'rick', 'warren', 'on'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'warren', 'on', 'rick'],
#        dtype='<U11'),
#  array(['is', 'what', 'yahoo'], dtype='<U5'),
#  array(['is', 'yahoo', 'what'], dtype='<U5'),
#  array(['what', 'is', 'yahoo'], dtype='<U5'),
#  array(['what', 'yahoo', 'is'], dtype='<U5'),
#  array(['yahoo', 'is', 'what'], dtype='<U5'),
#  array(['can', 'heart', 'how', 'i', 'lower', 'my', 'rate'], dtype='<U5'),
#  array(['can', 'heart', 'how', 'i', 'lower', 'rate', 'my'], dtype='<U5'),
#  array(['can', 'heart', 'how', 'i', 'my', 'lower', 'rate'], dtype='<U5'),
#  array(['can', 'heart', 'how', 'i', 'my', 'rate', 'lower'], dtype='<U5'),
#  array(['can', 'heart', 'how', 'i', 'rate', 'lower', 'my'], dtype='<U5'),
#  array(['im', 'in', 'interested', 'inuyasha'], dtype='<U10'),
#  array(['im', 'in', 'inuyasha', 'interested'], dtype='<U10'),
#  array(['im', 'interested', 'in', 'inuyasha'], dtype='<U10'),
#  array(['im', 'interested', 'inuyasha', 'in'], dtype='<U10'),
#  array(['im', 'inuyasha', 'in', 'interested'], dtype='<U10'),
#  array(['2', 'about', 'games', 'me', 'ps', 'tell'], dtype='<U5'),
#  array(['2', 'about', 'games', 'me', 'tell', 'ps'], dtype='<U5'),
#  array(['2', 'about', 'games', 'ps', 'me', 'tell'], dtype='<U5'),
#  array(['2', 'about', 'games', 'ps', 'tell', 'me'], dtype='<U5'),
#  array(['2', 'about', 'games', 'tell', 'me', 'ps'], dtype='<U5'),
#  array(['get', 'how', 'organised', 'to'], dtype='<U9'),
#  array(['get', 'how', 'to', 'organised'], dtype='<U9'),
#  array(['get', 'organised', 'how', 'to'], dtype='<U9'),
#  array(['get', 'organised', 'to', 'how'], dtype='<U9'),
#  array(['get', 'to', 'how', 'organised'], dtype='<U9'),
#  array(['about', 'diabetes', 'education', 'find', 'information', 'me'],
#        dtype='<U11'),
#  array(['about', 'diabetes', 'education', 'find', 'me', 'information'],
#        dtype='<U11'),
#  array(['about', 'diabetes', 'education', 'information', 'find', 'me'],
#        dtype='<U11'),
#  array(['about', 'diabetes', 'education', 'information', 'me', 'find'],
#        dtype='<U11'),
#  array(['about', 'diabetes', 'education', 'me', 'find', 'information'],
#        dtype='<U11'),
#  array(['about', 'atari', 'find', 'information'], dtype='<U11'),
#  array(['about', 'atari', 'information', 'find'], dtype='<U11'),
#  array(['about', 'find', 'atari', 'information'], dtype='<U11'),
#  array(['about', 'find', 'information', 'atari'], dtype='<U11'),
#  array(['about', 'information', 'atari', 'find'], dtype='<U11'),
#  array(['and', 'design', 'for', 'hosting', 'im', 'information', 'looking',
#         'on', 'web'], dtype='<U11'),
#  array(['and', 'design', 'for', 'hosting', 'im', 'information', 'looking',
#         'web', 'on'], dtype='<U11'),
#  array(['and', 'design', 'for', 'hosting', 'im', 'information', 'on',
#         'looking', 'web'], dtype='<U11'),
#  array(['and', 'design', 'for', 'hosting', 'im', 'information', 'on',
#         'web', 'looking'], dtype='<U11'),
#  array(['and', 'design', 'for', 'hosting', 'im', 'information', 'web',
#         'looking', 'on'], dtype='<U11'),
#  array(['about', 'elliptical', 'find', 'information', 'trainer'],
#        dtype='<U11'),
#  array(['about', 'elliptical', 'find', 'trainer', 'information'],
#        dtype='<U11'),
#  array(['about', 'elliptical', 'information', 'find', 'trainer'],
#        dtype='<U11'),
#  array(['about', 'elliptical', 'information', 'trainer', 'find'],
#        dtype='<U11'),
#  array(['about', 'elliptical', 'trainer', 'find', 'information'],
#        dtype='<U11'),
#  array(['about', 'cell', 'me', 'phones', 'tell'], dtype='<U6'),
#  array(['about', 'cell', 'me', 'tell', 'phones'], dtype='<U6'),
#  array(['about', 'cell', 'phones', 'me', 'tell'], dtype='<U6'),
#  array(['about', 'cell', 'phones', 'tell', 'me'], dtype='<U6'),
#  array(['about', 'cell', 'tell', 'me', 'phones'], dtype='<U6'),
#  array(['buy', 'gps', 'i', 'receiver', 'should', 'which'], dtype='<U8'),
#  array(['buy', 'gps', 'i', 'receiver', 'which', 'should'], dtype='<U8'),
#  array(['buy', 'gps', 'i', 'should', 'receiver', 'which'], dtype='<U8'),
#  array(['buy', 'gps', 'i', 'should', 'which', 'receiver'], dtype='<U8'),
#  array(['buy', 'gps', 'i', 'which', 'receiver', 'should'], dtype='<U8'),
#  array(['a', 'adopt', 'can', 'dog', 'how', 'i'], dtype='<U5'),
#  array(['a', 'adopt', 'can', 'dog', 'i', 'how'], dtype='<U5'),
#  array(['a', 'adopt', 'can', 'how', 'dog', 'i'], dtype='<U5'),
#  array(['a', 'adopt', 'can', 'how', 'i', 'dog'], dtype='<U5'),
#  array(['a', 'adopt', 'can', 'i', 'dog', 'how'], dtype='<U5'),
#  array(['about', 'disneyland', 'give', 'hotel', 'information', 'me'],
#        dtype='<U11'),
#  array(['about', 'disneyland', 'give', 'hotel', 'me', 'information'],
#        dtype='<U11'),
#  array(['about', 'disneyland', 'give', 'information', 'hotel', 'me'],
#        dtype='<U11'),
#  array(['about', 'disneyland', 'give', 'information', 'me', 'hotel'],
#        dtype='<U11'),
#  array(['about', 'disneyland', 'give', 'me', 'hotel', 'information'],
#        dtype='<U11'),
#  array(['change', 'house', 'how', 'in', 'the', 'the', 'to', 'toilet'],
#        dtype='<U6'),
#  array(['change', 'house', 'how', 'in', 'the', 'the', 'toilet', 'to'],
#        dtype='<U6'),
#  array(['change', 'house', 'how', 'in', 'the', 'to', 'the', 'toilet'],
#        dtype='<U6'),
#  array(['change', 'house', 'how', 'in', 'the', 'to', 'toilet', 'the'],
#        dtype='<U6'),
#  array(['change', 'house', 'how', 'in', 'the', 'toilet', 'the', 'to'],
#        dtype='<U6'),
#  array(['are', 'in', 'jobs', 'michigan', 'popular', 'the', 'what'],
#        dtype='<U8'),
#  array(['are', 'in', 'jobs', 'michigan', 'popular', 'what', 'the'],
#        dtype='<U8'),
#  array(['are', 'in', 'jobs', 'michigan', 'the', 'popular', 'what'],
#        dtype='<U8'),
#  array(['are', 'in', 'jobs', 'michigan', 'the', 'what', 'popular'],
#        dtype='<U8'),
#  array(['are', 'in', 'jobs', 'michigan', 'what', 'popular', 'the'],
#        dtype='<U8'),
#  array(['for', 'i', 'looking', 'm', 'man', 'music', 'the', '’'],
#        dtype='<U7'),
#  array(['for', 'i', 'looking', 'm', 'man', 'music', '’', 'the'],
#        dtype='<U7'),
#  array(['for', 'i', 'looking', 'm', 'man', 'the', 'music', '’'],
#        dtype='<U7'),
#  array(['for', 'i', 'looking', 'm', 'man', 'the', '’', 'music'],
#        dtype='<U7'),
#  array(['for', 'i', 'looking', 'm', 'man', '’', 'music', 'the'],
#        dtype='<U7'),
#  array(['about', 'find', 'garden', 'information', 'secret', 'the'],
#        dtype='<U11'),
#  array(['about', 'find', 'garden', 'information', 'the', 'secret'],
#        dtype='<U11'),
#  array(['about', 'find', 'garden', 'secret', 'information', 'the'],
#        dtype='<U11'),
#  array(['about', 'find', 'garden', 'secret', 'the', 'information'],
#        dtype='<U11'),
#  array(['about', 'find', 'garden', 'the', 'information', 'secret'],
#        dtype='<U11'),
#  array(['about', 'alexian', 'brothers', 'give', 'hospitals', 'information',
#         'me'], dtype='<U11'),
#  array(['about', 'alexian', 'brothers', 'give', 'hospitals', 'me',
#         'information'], dtype='<U11'),
#  array(['about', 'alexian', 'brothers', 'give', 'information', 'hospitals',
#         'me'], dtype='<U11'),
#  array(['about', 'alexian', 'brothers', 'give', 'information', 'me',
#         'hospitals'], dtype='<U11'),
#  array(['about', 'alexian', 'brothers', 'give', 'me', 'hospitals',
#         'information'], dtype='<U11'),
#  array(['about', 'antenna', 'me', 'tell', 'wilson'], dtype='<U7'),
#  array(['about', 'antenna', 'me', 'wilson', 'tell'], dtype='<U7'),
#  array(['about', 'antenna', 'tell', 'me', 'wilson'], dtype='<U7'),
#  array(['about', 'antenna', 'tell', 'wilson', 'me'], dtype='<U7'),
#  array(['about', 'antenna', 'wilson', 'me', 'tell'], dtype='<U7'),
#  array(['designs', 'flame', 'for', 'im', 'looking'], dtype='<U7'),
#  array(['designs', 'flame', 'for', 'looking', 'im'], dtype='<U7'),
#  array(['designs', 'flame', 'im', 'for', 'looking'], dtype='<U7'),
#  array(['designs', 'flame', 'im', 'looking', 'for'], dtype='<U7'),
#  array(['designs', 'flame', 'looking', 'for', 'im'], dtype='<U7'),
#  array(['about', 'college', 'find', 'information', 'mitchell'],
#        dtype='<U11'),
#  array(['about', 'college', 'find', 'mitchell', 'information'],
#        dtype='<U11'),
#  array(['about', 'college', 'information', 'find', 'mitchell'],
#        dtype='<U11'),
#  array(['about', 'college', 'information', 'mitchell', 'find'],
#        dtype='<U11'),
#  array(['about', 'college', 'mitchell', 'find', 'information'],
#        dtype='<U11'),
#  array(['dog', 'heat', 'info', 'on'], dtype='<U4'),
#  array(['dog', 'heat', 'on', 'info'], dtype='<U4'),
#  array(['dog', 'info', 'heat', 'on'], dtype='<U4'),
#  array(['dog', 'info', 'on', 'heat'], dtype='<U4'),
#  array(['dog', 'on', 'heat', 'info'], dtype='<U4'),
#  array(['about', 'avp', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'avp', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'me', 'avp', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'avp'], dtype='<U5'),
#  array(['about', 'tell', 'avp', 'me'], dtype='<U5'),
#  array(['channel', 'discovery', 'store'], dtype='<U9'),
#  array(['channel', 'store', 'discovery'], dtype='<U9'),
#  array(['discovery', 'channel', 'store'], dtype='<U9'),
#  array(['discovery', 'store', 'channel'], dtype='<U9'),
#  array(['store', 'channel', 'discovery'], dtype='<U9'),
#  array(['for', 'im', 'information', 'looking', 'of', 'on', 'president',
#         'states', 'the', 'the', 'united'], dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'of', 'on', 'president',
#         'states', 'the', 'united', 'the'], dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'of', 'on', 'president',
#         'states', 'united', 'the', 'the'], dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'of', 'on', 'president',
#         'the', 'states', 'the', 'united'], dtype='<U11'),
#  array(['for', 'im', 'information', 'looking', 'of', 'on', 'president',
#         'the', 'states', 'united', 'the'], dtype='<U11'),
#  array(['about', 'iron', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'iron', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'me', 'iron', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'iron'], dtype='<U5'),
#  array(['about', 'tell', 'iron', 'me'], dtype='<U5'),
#  array(['about', 'charleston', 'me', 'sc', 'tell', 'uss', 'yorktown'],
#        dtype='<U10'),
#  array(['about', 'charleston', 'me', 'sc', 'tell', 'yorktown', 'uss'],
#        dtype='<U10'),
#  array(['about', 'charleston', 'me', 'sc', 'uss', 'tell', 'yorktown'],
#        dtype='<U10'),
#  array(['about', 'charleston', 'me', 'sc', 'uss', 'yorktown', 'tell'],
#        dtype='<U10'),
#  array(['about', 'charleston', 'me', 'sc', 'yorktown', 'tell', 'uss'],
#        dtype='<U10'),
#  array(['about', 'ct', 'jobs', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'ct', 'jobs', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'ct', 'me', 'jobs', 'tell'], dtype='<U5'),
#  array(['about', 'ct', 'me', 'tell', 'jobs'], dtype='<U5'),
#  array(['about', 'ct', 'tell', 'jobs', 'me'], dtype='<U5'),
#  array(['about', 'find', 'information', 'penguins'], dtype='<U11'),
#  array(['about', 'find', 'penguins', 'information'], dtype='<U11'),
#  array(['about', 'information', 'find', 'penguins'], dtype='<U11'),
#  array(['about', 'information', 'penguins', 'find'], dtype='<U11'),
#  array(['about', 'penguins', 'find', 'information'], dtype='<U11'),
#  array(['a', 'build', 'fence', 'how', 'to'], dtype='<U5'),
#  array(['a', 'build', 'fence', 'to', 'how'], dtype='<U5'),
#  array(['a', 'build', 'how', 'fence', 'to'], dtype='<U5'),
#  array(['a', 'build', 'how', 'to', 'fence'], dtype='<U5'),
#  array(['a', 'build', 'to', 'fence', 'how'], dtype='<U5'),
#  array(['city', 'kansas', 'me', 'more', 'on', 'railroad', 'tell'],
#        dtype='<U8'),
#  array(['city', 'kansas', 'me', 'more', 'on', 'tell', 'railroad'],
#        dtype='<U8'),
#  array(['city', 'kansas', 'me', 'more', 'railroad', 'on', 'tell'],
#        dtype='<U8'),
#  array(['city', 'kansas', 'me', 'more', 'railroad', 'tell', 'on'],
#        dtype='<U8'),
#  array(['city', 'kansas', 'me', 'more', 'tell', 'on', 'railroad'],
#        dtype='<U8'),
#  array(['about', 'bellevue', 'me', 'tell'], dtype='<U8'),
#  array(['about', 'bellevue', 'tell', 'me'], dtype='<U8'),
#  array(['about', 'me', 'bellevue', 'tell'], dtype='<U8'),
#  array(['about', 'me', 'tell', 'bellevue'], dtype='<U8'),
#  array(['about', 'tell', 'bellevue', 'me'], dtype='<U8'),
#  array(['for', 'i', 'information', 'looking', 'm', 'on', 'worm', '’'],
#        dtype='<U11'),
#  array(['for', 'i', 'information', 'looking', 'm', 'on', '’', 'worm'],
#        dtype='<U11'),
#  array(['for', 'i', 'information', 'looking', 'm', 'worm', 'on', '’'],
#        dtype='<U11'),
#  array(['for', 'i', 'information', 'looking', 'm', 'worm', '’', 'on'],
#        dtype='<U11'),
#  array(['for', 'i', 'information', 'looking', 'm', '’', 'on', 'worm'],
#        dtype='<U11'),
#  array(['about', 'find', 'flushing', 'information'], dtype='<U11'),
#  array(['about', 'find', 'information', 'flushing'], dtype='<U11'),
#  array(['about', 'flushing', 'find', 'information'], dtype='<U11'),
#  array(['about', 'flushing', 'information', 'find'], dtype='<U11'),
#  array(['about', 'information', 'find', 'flushing'], dtype='<U11'),
#  array(['about', 'korean', 'language', 'me', 'tell'], dtype='<U8'),
#  array(['about', 'korean', 'language', 'tell', 'me'], dtype='<U8'),
#  array(['about', 'korean', 'me', 'language', 'tell'], dtype='<U8'),
#  array(['about', 'korean', 'me', 'tell', 'language'], dtype='<U8'),
#  array(['about', 'korean', 'tell', 'language', 'me'], dtype='<U8'),
#  array(['i', 'income', 'information', 'need', 'on', 'online', 'return',
#         'tax'], dtype='<U11'),
#  array(['i', 'income', 'information', 'need', 'on', 'online', 'tax',
#         'return'], dtype='<U11'),
#  array(['i', 'income', 'information', 'need', 'on', 'return', 'online',
#         'tax'], dtype='<U11'),
#  array(['i', 'income', 'information', 'need', 'on', 'return', 'tax',
#         'online'], dtype='<U11'),
#  array(['i', 'income', 'information', 'need', 'on', 'tax', 'online',
#         'return'], dtype='<U11'),
#  array(['for', 'im', 'information', 'levels', 'looking', 'on', 'vldl'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'levels', 'looking', 'vldl', 'on'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'levels', 'on', 'looking', 'vldl'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'levels', 'on', 'vldl', 'looking'],
#        dtype='<U11'),
#  array(['for', 'im', 'information', 'levels', 'vldl', 'looking', 'on'],
#        dtype='<U11'),
#  array(['about', 'find', 'information', 'me', 'pvc'], dtype='<U11'),
#  array(['about', 'find', 'information', 'pvc', 'me'], dtype='<U11'),
#  array(['about', 'find', 'me', 'information', 'pvc'], dtype='<U11'),
#  array(['about', 'find', 'me', 'pvc', 'information'], dtype='<U11'),
#  array(['about', 'find', 'pvc', 'information', 'me'], dtype='<U11'),
#  array(['find', 'for', 'instructions', 'me', 'sewing'], dtype='<U12'),
#  array(['find', 'for', 'instructions', 'sewing', 'me'], dtype='<U12'),
#  array(['find', 'for', 'me', 'instructions', 'sewing'], dtype='<U12'),
#  array(['find', 'for', 'me', 'sewing', 'instructions'], dtype='<U12'),
#  array(['find', 'for', 'sewing', 'instructions', 'me'], dtype='<U12'),
#  array(['be', 'be', 'is', 'not', 'or', 'question', 'that', 'the', 'to',
#         'to'], dtype='<U8'),
#  array(['be', 'be', 'is', 'not', 'or', 'question', 'that', 'to', 'the',
#         'to'], dtype='<U8'),
#  array(['be', 'be', 'is', 'not', 'or', 'question', 'that', 'to', 'to',
#         'the'], dtype='<U8'),
#  array(['be', 'be', 'is', 'not', 'or', 'question', 'the', 'that', 'to',
#         'to'], dtype='<U8'),
#  array(['be', 'be', 'is', 'not', 'or', 'question', 'the', 'to', 'that',
#         'to'], dtype='<U8'),
#  array(['about', 'find', 'information', 'sun', 'the'], dtype='<U11'),
#  array(['about', 'find', 'information', 'the', 'sun'], dtype='<U11'),
#  array(['about', 'find', 'sun', 'information', 'the'], dtype='<U11'),
#  array(['about', 'find', 'sun', 'the', 'information'], dtype='<U11'),
#  array(['about', 'find', 'the', 'information', 'sun'], dtype='<U11'),
#  array(['about', 'me', 'neil', 'tell', 'young'], dtype='<U5'),
#  array(['about', 'me', 'neil', 'young', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'neil', 'young'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'young', 'neil'], dtype='<U5'),
#  array(['about', 'me', 'young', 'neil', 'tell'], dtype='<U5'),
#  array(['about', 'find', 'information', 'tornadoes'], dtype='<U11'),
#  array(['about', 'find', 'tornadoes', 'information'], dtype='<U11'),
#  array(['about', 'information', 'find', 'tornadoes'], dtype='<U11'),
#  array(['about', 'information', 'tornadoes', 'find'], dtype='<U11'),
#  array(['about', 'tornadoes', 'find', 'information'], dtype='<U11'),
#  array(['about', 'bobcat', 'information'], dtype='<U11'),
#  array(['about', 'information', 'bobcat'], dtype='<U11'),
#  array(['bobcat', 'about', 'information'], dtype='<U11'),
#  array(['bobcat', 'information', 'about'], dtype='<U11'),
#  array(['information', 'about', 'bobcat'], dtype='<U11'),
#  array(['for', 'im', 'keyboard', 'looking', 'reviews'], dtype='<U8'),
#  array(['for', 'im', 'keyboard', 'reviews', 'looking'], dtype='<U8'),
#  array(['for', 'im', 'looking', 'keyboard', 'reviews'], dtype='<U8'),
#  array(['for', 'im', 'looking', 'reviews', 'keyboard'], dtype='<U8'),
#  array(['for', 'im', 'reviews', 'keyboard', 'looking'], dtype='<U8'),
#  array(['about', 'afganistan', 'me', 'tell'], dtype='<U10'),
#  array(['about', 'afganistan', 'tell', 'me'], dtype='<U10'),
#  array(['about', 'me', 'afganistan', 'tell'], dtype='<U10'),
#  array(['about', 'me', 'tell', 'afganistan'], dtype='<U10'),
#  array(['about', 'tell', 'afganistan', 'me'], dtype='<U10'),
#  array(['about', 'id', 'joints', 'learn', 'like', 'to'], dtype='<U6'),
#  array(['about', 'id', 'joints', 'learn', 'to', 'like'], dtype='<U6'),
#  array(['about', 'id', 'joints', 'like', 'learn', 'to'], dtype='<U6'),
#  array(['about', 'id', 'joints', 'like', 'to', 'learn'], dtype='<U6'),
#  array(['about', 'id', 'joints', 'to', 'learn', 'like'], dtype='<U6'),
#  array(['are', 'continental', 'plates', 'what'], dtype='<U11'),
#  array(['are', 'continental', 'what', 'plates'], dtype='<U11'),
#  array(['are', 'plates', 'continental', 'what'], dtype='<U11'),
#  array(['are', 'plates', 'what', 'continental'], dtype='<U11'),
#  array(['are', 'what', 'continental', 'plates'], dtype='<U11'),
#  array(['about', 'can', 'find', 'forearm', 'i', 'information', 'pain',
#         'where'], dtype='<U11'),
#  array(['about', 'can', 'find', 'forearm', 'i', 'information', 'where',
#         'pain'], dtype='<U11'),
#  array(['about', 'can', 'find', 'forearm', 'i', 'pain', 'information',
#         'where'], dtype='<U11'),
#  array(['about', 'can', 'find', 'forearm', 'i', 'pain', 'where',
#         'information'], dtype='<U11'),
#  array(['about', 'can', 'find', 'forearm', 'i', 'where', 'information',
#         'pain'], dtype='<U11'),
#  array(['give', 'information', 'me', 'ocd', 'on'], dtype='<U11'),
#  array(['give', 'information', 'me', 'on', 'ocd'], dtype='<U11'),
#  array(['give', 'information', 'ocd', 'me', 'on'], dtype='<U11'),
#  array(['give', 'information', 'ocd', 'on', 'me'], dtype='<U11'),
#  array(['give', 'information', 'on', 'me', 'ocd'], dtype='<U11'),
#  array(['am', 'car', 'for', 'i', 'looking', 'of', 'parts', 'sources',
#         'used'], dtype='<U7'),
#  array(['am', 'car', 'for', 'i', 'looking', 'of', 'parts', 'used',
#         'sources'], dtype='<U7'),
#  array(['am', 'car', 'for', 'i', 'looking', 'of', 'sources', 'parts',
#         'used'], dtype='<U7'),
#  array(['am', 'car', 'for', 'i', 'looking', 'of', 'sources', 'used',
#         'parts'], dtype='<U7'),
#  array(['am', 'car', 'for', 'i', 'looking', 'of', 'used', 'parts',
#         'sources'], dtype='<U7'),
#  array(['about', 'me', 'mgb', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'mgb'], dtype='<U5'),
#  array(['about', 'mgb', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'mgb', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'tell', 'me', 'mgb'], dtype='<U5'),
#  array(['about', 'information', 'raffles'], dtype='<U11'),
#  array(['about', 'raffles', 'information'], dtype='<U11'),
#  array(['information', 'about', 'raffles'], dtype='<U11'),
#  array(['information', 'raffles', 'about'], dtype='<U11'),
#  array(['raffles', 'about', 'information'], dtype='<U11'),
#  array(['about', 'me', 'rice', 'tell'], dtype='<U5'),
#  array(['about', 'me', 'tell', 'rice'], dtype='<U5'),
#  array(['about', 'rice', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'rice', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'tell', 'me', 'rice'], dtype='<U5'),
#  array(['about', 'africa', 'for', 'im', 'information', 'looking', 'south'],
#        dtype='<U11'),
#  array(['about', 'africa', 'for', 'im', 'information', 'south', 'looking'],
#        dtype='<U11'),
#  array(['about', 'africa', 'for', 'im', 'looking', 'information', 'south'],
#        dtype='<U11'),
#  array(['about', 'africa', 'for', 'im', 'looking', 'south', 'information'],
#        dtype='<U11'),
#  array(['about', 'africa', 'for', 'im', 'south', 'information', 'looking'],
#        dtype='<U11'),
# ...
#  array(['acid', 'batteries', 'for', 'im', 'information', 'lead', 'looking',
#         'on', 'recycling'], dtype='<U11'),
#  array(['acid', 'batteries', 'for', 'im', 'information', 'lead', 'looking',
#         'recycling', 'on'], dtype='<U11'),
#  array(['acid', 'batteries', 'for', 'im', 'information', 'lead', 'on',
#         'looking', 'recycling'], dtype='<U11'),
#  array(['acid', 'batteries', 'for', 'im', 'information', 'lead', 'on',
#         'recycling', 'looking'], dtype='<U11'),
#  array(['acid', 'batteries', 'for', 'im', 'information', 'lead',
#         'recycling', 'looking', 'on'], dtype='<U11'),
#  array(['can', 'cheap', 'find', 'i', 'internet', 'where'], dtype='<U8'),
#  array(['can', 'cheap', 'find', 'i', 'where', 'internet'], dtype='<U8'),
#  array(['can', 'cheap', 'find', 'internet', 'i', 'where'], dtype='<U8'),
#  array(['can', 'cheap', 'find', 'internet', 'where', 'i'], dtype='<U8'),
#  array(['can', 'cheap', 'find', 'where', 'i', 'internet'], dtype='<U8'),
#  array(['about', 'cj', 'madam', 'me', 'tell', 'walker'], dtype='<U6'),
#  array(['about', 'cj', 'madam', 'me', 'walker', 'tell'], dtype='<U6'),
#  array(['about', 'cj', 'madam', 'tell', 'me', 'walker'], dtype='<U6'),
#  array(['about', 'cj', 'madam', 'tell', 'walker', 'me'], dtype='<U6'),
#  array(['about', 'cj', 'madam', 'walker', 'me', 'tell'], dtype='<U6'),
#  array(['child', 'in', 'indiana', 'support'], dtype='<U7'),
#  array(['child', 'in', 'support', 'indiana'], dtype='<U7'),
#  array(['child', 'indiana', 'in', 'support'], dtype='<U7'),
#  array(['child', 'indiana', 'support', 'in'], dtype='<U7'),
#  array(['child', 'support', 'in', 'indiana'], dtype='<U7'),
#  array(['about', 'and', 'me', 'reach', 'sit', 'tell', 'test', 'the'],
#        dtype='<U5'),
#  array(['about', 'and', 'me', 'reach', 'sit', 'tell', 'the', 'test'],
#        dtype='<U5'),
#  array(['about', 'and', 'me', 'reach', 'sit', 'test', 'tell', 'the'],
#        dtype='<U5'),
#  array(['about', 'and', 'me', 'reach', 'sit', 'test', 'the', 'tell'],
#        dtype='<U5'),
#  array(['about', 'and', 'me', 'reach', 'sit', 'the', 'tell', 'test'],
#        dtype='<U5'),
#  array(['are', 'characteristics', 'of', 'uranus', 'what'], dtype='<U15'),
#  array(['are', 'characteristics', 'of', 'what', 'uranus'], dtype='<U15'),
#  array(['are', 'characteristics', 'uranus', 'of', 'what'], dtype='<U15'),
#  array(['are', 'characteristics', 'uranus', 'what', 'of'], dtype='<U15'),
#  array(['are', 'characteristics', 'what', 'of', 'uranus'], dtype='<U15'),
#  array(['about', 'electronic', 'me', 'shoot', 'skeet', 'tell'],
#        dtype='<U10'),
#  array(['about', 'electronic', 'me', 'shoot', 'tell', 'skeet'],
#        dtype='<U10'),
#  array(['about', 'electronic', 'me', 'skeet', 'shoot', 'tell'],
#        dtype='<U10'),
#  array(['about', 'electronic', 'me', 'skeet', 'tell', 'shoot'],
#        dtype='<U10'),
#  array(['about', 'electronic', 'me', 'tell', 'shoot', 'skeet'],
#        dtype='<U10'),
#  array(['become', 'can', 'can', 'highway', 'how', 'one', 'patrol'],
#        dtype='<U7'),
#  array(['become', 'can', 'can', 'highway', 'how', 'patrol', 'one'],
#        dtype='<U7'),
#  array(['become', 'can', 'can', 'highway', 'one', 'how', 'patrol'],
#        dtype='<U7'),
#  array(['become', 'can', 'can', 'highway', 'one', 'patrol', 'how'],
#        dtype='<U7'),
#  array(['become', 'can', 'can', 'highway', 'patrol', 'how', 'one'],
#        dtype='<U7'),
#  array(['403b', 'a', 'is', 'what'], dtype='<U4'),
#  array(['403b', 'a', 'what', 'is'], dtype='<U4'),
#  array(['403b', 'is', 'a', 'what'], dtype='<U4'),
#  array(['403b', 'is', 'what', 'a'], dtype='<U4'),
#  array(['403b', 'what', 'a', 'is'], dtype='<U4'),
#  array(['about', 'find', 'information', 'last', 'me', 'painting', 'supper',
#         'the'], dtype='<U11'),
#  array(['about', 'find', 'information', 'last', 'me', 'painting', 'the',
#         'supper'], dtype='<U11'),
#  array(['about', 'find', 'information', 'last', 'me', 'supper', 'painting',
#         'the'], dtype='<U11'),
#  array(['about', 'find', 'information', 'last', 'me', 'supper', 'the',
#         'painting'], dtype='<U11'),
#  array(['about', 'find', 'information', 'last', 'me', 'the', 'painting',
#         'supper'], dtype='<U11'),
#  array(['band', 'beatles', 'for', 'im', 'information', 'looking', 'on',
#         'rock', 'the'], dtype='<U11'),
#  array(['band', 'beatles', 'for', 'im', 'information', 'looking', 'on',
#         'the', 'rock'], dtype='<U11'),
#  array(['band', 'beatles', 'for', 'im', 'information', 'looking', 'rock',
#         'on', 'the'], dtype='<U11'),
#  array(['band', 'beatles', 'for', 'im', 'information', 'looking', 'rock',
#         'the', 'on'], dtype='<U11'),
#  array(['band', 'beatles', 'for', 'im', 'information', 'looking', 'the',
#         'on', 'rock'], dtype='<U11'),
#  array(['about', 'for', 'furniture', 'me', 'small', 'spaces', 'tell'],
#        dtype='<U9'),
#  array(['about', 'for', 'furniture', 'me', 'small', 'tell', 'spaces'],
#        dtype='<U9'),
#  array(['about', 'for', 'furniture', 'me', 'spaces', 'small', 'tell'],
#        dtype='<U9'),
#  array(['about', 'for', 'furniture', 'me', 'spaces', 'tell', 'small'],
#        dtype='<U9'),
#  array(['about', 'for', 'furniture', 'me', 'tell', 'small', 'spaces'],
#        dtype='<U9'),
#  array(['im', 'in', 'interested', 'poker', 'tournaments'], dtype='<U11'),
#  array(['im', 'in', 'interested', 'tournaments', 'poker'], dtype='<U11'),
#  array(['im', 'in', 'poker', 'interested', 'tournaments'], dtype='<U11'),
#  array(['im', 'in', 'poker', 'tournaments', 'interested'], dtype='<U11'),
#  array(['im', 'in', 'tournaments', 'interested', 'poker'], dtype='<U11'),
#  array(['about', 'me', 'scooters', 'tell'], dtype='<U8'),
#  array(['about', 'me', 'tell', 'scooters'], dtype='<U8'),
#  array(['about', 'scooters', 'me', 'tell'], dtype='<U8'),
#  array(['about', 'scooters', 'tell', 'me'], dtype='<U8'),
#  array(['about', 'tell', 'me', 'scooters'], dtype='<U8'),
#  array(['about', 'howard', 'me', 'ron', 'tell'], dtype='<U6'),
#  array(['about', 'howard', 'me', 'tell', 'ron'], dtype='<U6'),
#  array(['about', 'howard', 'ron', 'me', 'tell'], dtype='<U6'),
#  array(['about', 'howard', 'ron', 'tell', 'me'], dtype='<U6'),
#  array(['about', 'howard', 'tell', 'me', 'ron'], dtype='<U6'),
#  array(['a', 'becoming', 'for', 'im', 'information', 'looking', 'on',
#         'paralegal'], dtype='<U11'),
#  array(['a', 'becoming', 'for', 'im', 'information', 'looking',
#         'paralegal', 'on'], dtype='<U11'),
#  array(['a', 'becoming', 'for', 'im', 'information', 'on', 'looking',
#         'paralegal'], dtype='<U11'),
#  array(['a', 'becoming', 'for', 'im', 'information', 'on', 'paralegal',
#         'looking'], dtype='<U11'),
#  array(['a', 'becoming', 'for', 'im', 'information', 'paralegal',
#         'looking', 'on'], dtype='<U11'),
#  array(['cook', 'how', 'pork', 'tenderlion', 'to'], dtype='<U10'),
#  array(['cook', 'how', 'pork', 'to', 'tenderlion'], dtype='<U10'),
#  array(['cook', 'how', 'tenderlion', 'pork', 'to'], dtype='<U10'),
#  array(['cook', 'how', 'tenderlion', 'to', 'pork'], dtype='<U10'),
#  array(['cook', 'how', 'to', 'pork', 'tenderlion'], dtype='<U10'),
#  array(['coins', 'i', 'in', 'interested', 'm', 'old', '’'], dtype='<U10'),
#  array(['coins', 'i', 'in', 'interested', 'm', '’', 'old'], dtype='<U10'),
#  array(['coins', 'i', 'in', 'interested', 'old', 'm', '’'], dtype='<U10'),
#  array(['coins', 'i', 'in', 'interested', 'old', '’', 'm'], dtype='<U10'),
#  array(['coins', 'i', 'in', 'interested', '’', 'm', 'old'], dtype='<U10'),
#  array(['can', 'how', 'i', 'quick', 'smoking'], dtype='<U7'),
#  array(['can', 'how', 'i', 'smoking', 'quick'], dtype='<U7'),
#  array(['can', 'how', 'quick', 'i', 'smoking'], dtype='<U7'),
#  array(['can', 'how', 'quick', 'smoking', 'i'], dtype='<U7'),
#  array(['can', 'how', 'smoking', 'i', 'quick'], dtype='<U7'),
#  array(['civil', 'i', 'in', 'interested', 'm', 'movement', 'right', '’'],
#        dtype='<U10'),
#  array(['civil', 'i', 'in', 'interested', 'm', 'movement', '’', 'right'],
#        dtype='<U10'),
#  array(['civil', 'i', 'in', 'interested', 'm', 'right', 'movement', '’'],
#        dtype='<U10'),
#  array(['civil', 'i', 'in', 'interested', 'm', 'right', '’', 'movement'],
#        dtype='<U10'),
#  array(['civil', 'i', 'in', 'interested', 'm', '’', 'movement', 'right'],
#        dtype='<U10'),
#  array(['condos', 'find', 'florida', 'in'], dtype='<U7'),
#  array(['condos', 'find', 'in', 'florida'], dtype='<U7'),
#  array(['condos', 'florida', 'find', 'in'], dtype='<U7'),
#  array(['condos', 'florida', 'in', 'find'], dtype='<U7'),
#  array(['condos', 'in', 'find', 'florida'], dtype='<U7'),
#  array(['about', 'breeds', 'designer', 'dog', 'me', 'tell'], dtype='<U8'),
#  array(['about', 'breeds', 'designer', 'dog', 'tell', 'me'], dtype='<U8'),
#  array(['about', 'breeds', 'designer', 'me', 'dog', 'tell'], dtype='<U8'),
#  array(['about', 'breeds', 'designer', 'me', 'tell', 'dog'], dtype='<U8'),
#  array(['about', 'breeds', 'designer', 'tell', 'dog', 'me'], dtype='<U8'),
#  array(['about', 'center', 'convention', 'county', 'for', 'information',
#         'looking', 'orange', 'the'], dtype='<U11'),
#  array(['about', 'center', 'convention', 'county', 'for', 'information',
#         'looking', 'the', 'orange'], dtype='<U11'),
#  array(['about', 'center', 'convention', 'county', 'for', 'information',
#         'orange', 'looking', 'the'], dtype='<U11'),
#  array(['about', 'center', 'convention', 'county', 'for', 'information',
#         'orange', 'the', 'looking'], dtype='<U11'),
#  array(['about', 'center', 'convention', 'county', 'for', 'information',
#         'the', 'looking', 'orange'], dtype='<U11'),
#  array(['about', 'annuity', 'for', 'me', 'more', 'tax', 'tell', 'usa'],
#        dtype='<U7'),
#  array(['about', 'annuity', 'for', 'me', 'more', 'tax', 'usa', 'tell'],
#        dtype='<U7'),
#  array(['about', 'annuity', 'for', 'me', 'more', 'tell', 'tax', 'usa'],
#        dtype='<U7'),
#  array(['about', 'annuity', 'for', 'me', 'more', 'tell', 'usa', 'tax'],
#        dtype='<U7'),
#  array(['about', 'annuity', 'for', 'me', 'more', 'usa', 'tax', 'tell'],
#        dtype='<U7'),
#  array(['about', 'border', 'me', 'patrol', 'tell', 'texas'], dtype='<U6'),
#  array(['about', 'border', 'me', 'patrol', 'texas', 'tell'], dtype='<U6'),
#  array(['about', 'border', 'me', 'tell', 'patrol', 'texas'], dtype='<U6'),
#  array(['about', 'border', 'me', 'tell', 'texas', 'patrol'], dtype='<U6'),
#  array(['about', 'border', 'me', 'texas', 'patrol', 'tell'], dtype='<U6'),
#  array(['about', 'id', 'learn', 'like', 'moths', 'to'], dtype='<U5'),
#  array(['about', 'id', 'learn', 'like', 'to', 'moths'], dtype='<U5'),
#  array(['about', 'id', 'learn', 'moths', 'like', 'to'], dtype='<U5'),
#  array(['about', 'id', 'learn', 'moths', 'to', 'like'], dtype='<U5'),
#  array(['about', 'id', 'learn', 'to', 'like', 'moths'], dtype='<U5'),
#  array(['air', 'give', 'information', 'me', 'travel'], dtype='<U11'),
#  array(['air', 'give', 'information', 'travel', 'me'], dtype='<U11'),
#  array(['air', 'give', 'me', 'information', 'travel'], dtype='<U11'),
#  array(['air', 'give', 'me', 'travel', 'information'], dtype='<U11'),
#  array(['air', 'give', 'travel', 'information', 'me'], dtype='<U11'),
#  array(['find', 'gardens', 'information', 'on', 'raised'], dtype='<U11'),
#  array(['find', 'gardens', 'information', 'raised', 'on'], dtype='<U11'),
#  array(['find', 'gardens', 'on', 'information', 'raised'], dtype='<U11'),
#  array(['find', 'gardens', 'on', 'raised', 'information'], dtype='<U11'),
#  array(['find', 'gardens', 'raised', 'information', 'on'], dtype='<U11'),
#  array(['dieting', 'for', 'im', 'information', 'looking', 'on'],
#        dtype='<U11'),
#  array(['dieting', 'for', 'im', 'information', 'on', 'looking'],
#        dtype='<U11'),
#  array(['dieting', 'for', 'im', 'looking', 'information', 'on'],
#        dtype='<U11'),
#  array(['dieting', 'for', 'im', 'looking', 'on', 'information'],
#        dtype='<U11'),
#  array(['dieting', 'for', 'im', 'on', 'information', 'looking'],
#        dtype='<U11'),
#  array(['about', 'bart', 'me', 'sf', 'tell'], dtype='<U5'),
#  array(['about', 'bart', 'me', 'tell', 'sf'], dtype='<U5'),
#  array(['about', 'bart', 'sf', 'me', 'tell'], dtype='<U5'),
#  array(['about', 'bart', 'sf', 'tell', 'me'], dtype='<U5'),
#  array(['about', 'bart', 'tell', 'me', 'sf'], dtype='<U5'),
#  array(['invented', 'music', 'who'], dtype='<U8'),
#  array(['invented', 'who', 'music'], dtype='<U8'),
#  array(['music', 'invented', 'who'], dtype='<U8'),
#  array(['music', 'who', 'invented'], dtype='<U8'),
#  array(['who', 'invented', 'music'], dtype='<U8'),
#  array(['about', 'er', 'me', 'show', 'television', 'tell'], dtype='<U10'),
#  array(['about', 'er', 'me', 'show', 'tell', 'television'], dtype='<U10'),
#  array(['about', 'er', 'me', 'television', 'show', 'tell'], dtype='<U10'),
#  array(['about', 'er', 'me', 'television', 'tell', 'show'], dtype='<U10'),
#  array(['about', 'er', 'me', 'tell', 'show', 'television'], dtype='<U10'),
#  array(['about', 'find', 'information', 'the', 'wall'], dtype='<U11'),
#  array(['about', 'find', 'information', 'wall', 'the'], dtype='<U11'),
#  array(['about', 'find', 'the', 'information', 'wall'], dtype='<U11'),
#  array(['about', 'find', 'the', 'wall', 'information'], dtype='<U11'),
#  array(['about', 'find', 'wall', 'information', 'the'], dtype='<U11'),
#  array(['about', 'give', 'information', 'me', 'titan'], dtype='<U11'),
#  array(['about', 'give', 'information', 'titan', 'me'], dtype='<U11'),
#  array(['about', 'give', 'me', 'information', 'titan'], dtype='<U11'),
#  array(['about', 'give', 'me', 'titan', 'information'], dtype='<U11'),
#  array(['about', 'give', 'titan', 'information', 'me'], dtype='<U11'),
#  array(['find', 'les', 'me', 'miserables', 'of', 'reviews', 'the'],
#        dtype='<U10'),
#  array(['find', 'les', 'me', 'miserables', 'of', 'the', 'reviews'],
#        dtype='<U10'),
#  array(['find', 'les', 'me', 'miserables', 'reviews', 'of', 'the'],
#        dtype='<U10'),
#  array(['find', 'les', 'me', 'miserables', 'reviews', 'the', 'of'],
#        dtype='<U10'),
#  array(['find', 'les', 'me', 'miserables', 'the', 'of', 'reviews'],
#        dtype='<U10'),
#  array(['about', 'benefits', 'chocolate', 'dark', 'health', 'me', 'tell'],
#        dtype='<U9'),
#  array(['about', 'benefits', 'chocolate', 'dark', 'health', 'tell', 'me'],
#        dtype='<U9'),
#  array(['about', 'benefits', 'chocolate', 'dark', 'me', 'health', 'tell'],
#        dtype='<U9'),
#  array(['about', 'benefits', 'chocolate', 'dark', 'me', 'tell', 'health'],
#        dtype='<U9'),
#  array(['about', 'benefits', 'chocolate', 'dark', 'tell', 'health', 'me'],
#        dtype='<U9'),
#  array(['bio', 'bush', 'george', 'me', 'of', 'sr', 'tell'], dtype='<U6'),
#  array(['bio', 'bush', 'george', 'me', 'of', 'tell', 'sr'], dtype='<U6'),
#  array(['bio', 'bush', 'george', 'me', 'sr', 'of', 'tell'], dtype='<U6'),
#  array(['bio', 'bush', 'george', 'me', 'sr', 'tell', 'of'], dtype='<U6'),
#  array(['bio', 'bush', 'george', 'me', 'tell', 'of', 'sr'], dtype='<U6'),
#  array(['about', 'me', 'more', 'presidents', 'tell', 'us'], dtype='<U10'),
#  array(['about', 'me', 'more', 'presidents', 'us', 'tell'], dtype='<U10'),
#  array(['about', 'me', 'more', 'tell', 'presidents', 'us'], dtype='<U10'),
#  array(['about', 'me', 'more', 'tell', 'us', 'presidents'], dtype='<U10'),
#  array(['about', 'me', 'more', 'us', 'presidents', 'tell'], dtype='<U10'),
#  array(['a', 'about', 'folk', 'for', 'me', 'remedies', 'sore', 'tell',
#         'throat'], dtype='<U8'),
#  array(['a', 'about', 'folk', 'for', 'me', 'remedies', 'sore', 'throat',
#         'tell'], dtype='<U8'),
#  array(['a', 'about', 'folk', 'for', 'me', 'remedies', 'tell', 'sore',
#         'throat'], dtype='<U8'),
#  array(['a', 'about', 'folk', 'for', 'me', 'remedies', 'tell', 'throat',
#         'sore'], dtype='<U8'),
#  array(['a', 'about', 'folk', 'for', 'me', 'remedies', 'throat', 'sore',
#         'tell'], dtype='<U8'),
#  array(['a', 'do', 'how', 'knot', 'tie', 'windsor', 'you'], dtype='<U7'),
#  array(['a', 'do', 'how', 'knot', 'tie', 'you', 'windsor'], dtype='<U7'),
#  array(['a', 'do', 'how', 'knot', 'windsor', 'tie', 'you'], dtype='<U7'),
#  array(['a', 'do', 'how', 'knot', 'windsor', 'you', 'tie'], dtype='<U7'),
#  array(['a', 'do', 'how', 'knot', 'you', 'tie', 'windsor'], dtype='<U7')]

# %%
' '.join(inputs_aug[0])
# Out:
# 'about family me obama tell tree'

# %%
inputs = [' '.join(req) for req in inputs_aug]
inputs
# Out:
# ['about family me obama tell tree',
#  'about family me obama tree tell',
#  'about family me tell obama tree',
#  'about family me tell tree obama',
#  'about family me tree obama tell',
#  'creek farm fickle is what',
#  'creek farm fickle what is',
#  'creek farm is fickle what',
#  'creek farm is what fickle',
#  'creek farm what fickle is',
#  'about county me medical services sonoma tell',
#  'about county me medical services tell sonoma',
#  'about county me medical sonoma services tell',
#  'about county me medical sonoma tell services',
#  'about county me medical tell services sonoma',
#  'about brester me of owen ralph tell',
#  'about brester me of owen tell ralph',
#  'about brester me of ralph owen tell',
#  'about brester me of ralph tell owen',
#  'about brester me of tell owen ralph',
#  'about clinic fl for im information jacksonville looking mayo',
#  'about clinic fl for im information jacksonville mayo looking',
#  'about clinic fl for im information looking jacksonville mayo',
#  'about clinic fl for im information looking mayo jacksonville',
#  'about clinic fl for im information mayo jacksonville looking',
#  'for gmat how prepare the to',
#  'for gmat how prepare to the',
#  'for gmat how the prepare to',
#  'for gmat how the to prepare',
#  'for gmat how to prepare the',
#  'about dogs id in learn like lymphoma to',
#  'about dogs id in learn like to lymphoma',
#  'about dogs id in learn lymphoma like to',
#  'about dogs id in learn lymphoma to like',
#  'about dogs id in learn to like lymphoma',
#  'good heater is kenmore',
#  'good heater kenmore is',
#  'good is heater kenmore',
#  'good is kenmore heater',
#  'good kenmore heater is',
#  '2140 about hp me mini more tell',
#  '2140 about hp me mini tell more',
#  '2140 about hp me more mini tell',
#  '2140 about hp me more tell mini',
#  '2140 about hp me tell mini more',
#  'about laboratory me northwest pacific tell the',
#  'about laboratory me northwest pacific the tell',
#  'about laboratory me northwest tell pacific the',
#  'about laboratory me northwest tell the pacific',
#  'about laboratory me northwest the pacific tell',
#  'board california franchise is tax what',
#  'board california franchise is what tax',
#  'board california franchise tax is what',
#  'board california franchise tax what is',
#  'board california franchise what is tax',
#  'are asbestos dangers of specific what',
#  'are asbestos dangers of what specific',
#  'are asbestos dangers specific of what',
#  'are asbestos dangers specific what of',
#  'are asbestos dangers what of specific',
#  'a after an how interview letter thank to write you',
#  'a after an how interview letter thank to you write',
#  'a after an how interview letter thank write to you',
#  'a after an how interview letter thank write you to',
#  'a after an how interview letter thank you to write',
#  'disc hire how jockey to',
#  'disc hire how to jockey',
#  'disc hire jockey how to',
#  'disc hire jockey to how',
#  'disc hire to how jockey',
#  'computer on tv',
#  'computer tv on',
#  'on computer tv',
#  'on tv computer',
#  'tv computer on',
#  'about cemetry culpeper me more national tell',
#  'about cemetry culpeper me more tell national',
#  'about cemetry culpeper me national more tell',
#  'about cemetry culpeper me national tell more',
#  'about cemetry culpeper me tell more national',
#  'about bowflex me power pro tell',
#  'about bowflex me power tell pro',
#  'about bowflex me pro power tell',
#  'about bowflex me pro tell power',
#  'about bowflex me tell power pro',
#  'and butter margarine',
#  'and margarine butter',
#  'butter and margarine',
#  'butter margarine and',
#  'margarine and butter',
#  'county duchess for im information looking on tourism',
#  'county duchess for im information looking tourism on',
#  'county duchess for im information on looking tourism',
#  'county duchess for im information on tourism looking',
#  'county duchess for im information tourism looking on',
#  'about food information iowas me program stamp tell',
#  'about food information iowas me program tell stamp',
#  'about food information iowas me stamp program tell',
#  'about food information iowas me stamp tell program',
#  'about food information iowas me tell program stamp',
#  'map',
#  'employer equal is opportunity what',
#  'employer equal is what opportunity',
#  'employer equal opportunity is what',
#  'employer equal opportunity what is',
#  'employer equal what is opportunity',
#  'day im in interested mothers songs',
#  'day im in interested songs mothers',
#  'day im in mothers interested songs',
#  'day im in mothers songs interested',
#  'day im in songs interested mothers',
#  'about me nile of source tell the',
#  'about me nile of source the tell',
#  'about me nile of tell source the',
#  'about me nile of tell the source',
#  'about me nile of the source tell',
#  'about american me military tell university',
#  'about american me military university tell',
#  'about american me tell military university',
#  'about american me tell university military',
#  'about american me university military tell',
#  'about and gem me rock shows tell',
#  'about and gem me rock tell shows',
#  'about and gem me shows rock tell',
#  'about and gem me shows tell rock',
#  'about and gem me tell rock shows',
#  'chemical company for im information jax looking on',
#  'chemical company for im information jax on looking',
#  'chemical company for im information looking jax on',
#  'chemical company for im information looking on jax',
#  'chemical company for im information on jax looking',
#  'dinosaurs im in interested',
#  'dinosaurs im interested in',
#  'dinosaurs in im interested',
#  'dinosaurs in interested im',
#  'dinosaurs interested im in',
#  'about east high information ridge school',
#  'about east high information school ridge',
#  'about east high ridge information school',
#  'about east high ridge school information',
#  'about east high school information ridge',
#  'dmv how in register to va',
#  'dmv how in register va to',
#  'dmv how in to register va',
#  'dmv how in to va register',
#  'dmv how in va register to',
#  'arkansas clubs health in me more on tell',
#  'arkansas clubs health in me more tell on',
#  'arkansas clubs health in me on more tell',
#  'arkansas clubs health in me on tell more',
#  'arkansas clubs health in me tell more on',
#  'a buy can i trombone where',
#  'a buy can i where trombone',
#  'a buy can trombone i where',
#  'a buy can trombone where i',
#  'a buy can where i trombone',
#  'about for me shade tell vines',
#  'about for me shade vines tell',
#  'about for me tell shade vines',
#  'about for me tell vines shade',
#  'about for me vines shade tell',
#  'can do i in library regional sherwood what',
#  'can do i in library regional what sherwood',
#  'can do i in library sherwood regional what',
#  'can do i in library sherwood what regional',
#  'can do i in library what regional sherwood',
#  'about me personal property tangible tax tell',
#  'about me personal property tangible tell tax',
#  'about me personal property tax tangible tell',
#  'about me personal property tax tell tangible',
#  'about me personal property tell tangible tax',
#  'and imclone is martha stewart what',
#  'and imclone is martha what stewart',
#  'and imclone is stewart martha what',
#  'and imclone is stewart what martha',
#  'and imclone is what martha stewart',
#  'about at me national park tell uplift yellowstone',
#  'about at me national park tell yellowstone uplift',
#  'about at me national park uplift tell yellowstone',
#  'about at me national park uplift yellowstone tell',
#  'about at me national park yellowstone tell uplift',
#  'espn give information me sports',
#  'espn give information sports me',
#  'espn give me information sports',
#  'espn give me sports information',
#  'espn give sports information me',
#  'about me pocono tell',
#  'about me tell pocono',
#  'about pocono me tell',
#  'about pocono tell me',
#  'about tell me pocono',
#  'figs',
#  'about i information need of phoenix the university',
#  'about i information need of phoenix university the',
#  'about i information need of the phoenix university',
#  'about i information need of the university phoenix',
#  'about i information need of university phoenix the',
#  'design how i septic should system the use',
#  'design how i septic should system use the',
#  'design how i septic should the system use',
#  'design how i septic should the use system',
#  'design how i septic should use system the',
#  'find information on porterville',
#  'find information porterville on',
#  'find on information porterville',
#  'find on porterville information',
#  'find porterville information on',
#  'about and arizona fish for game im in information looking',
#  'about and arizona fish for game im in looking information',
#  'about and arizona fish for game im information in looking',
#  'about and arizona fish for game im information looking in',
#  'about and arizona fish for game im looking in information',
#  'are best for grilling recepies the what',
#  'are best for grilling recepies what the',
#  'are best for grilling the recepies what',
#  'are best for grilling the what recepies',
#  'are best for grilling what recepies the',
#  'about dnr me more tell',
#  'about dnr me tell more',
#  'about dnr more me tell',
#  'about dnr more tell me',
#  'about dnr tell me more',
#  'arkansas do in to what',
#  'arkansas do in what to',
#  'arkansas do to in what',
#  'arkansas do to what in',
#  'arkansas do what in to',
#  'about barbados me tell',
#  'about barbados tell me',
#  'about me barbados tell',
#  'about me tell barbados',
#  'about tell barbados me',
#  'are causes lipoma of the tumors what',
#  'are causes lipoma of the what tumors',
#  'are causes lipoma of tumors the what',
#  'are causes lipoma of tumors what the',
#  'are causes lipoma of what the tumors',
#  'find fractures hip information on',
#  'find fractures hip on information',
#  'find fractures information hip on',
#  'find fractures information on hip',
#  'find fractures on hip information',
#  'a are heartattack of signs what',
#  'a are heartattack of what signs',
#  'a are heartattack signs of what',
#  'a are heartattack signs what of',
#  'a are heartattack what of signs',
#  'about me stripping tell weather',
#  'about me stripping weather tell',
#  'about me tell stripping weather',
#  'about me tell weather stripping',
#  'about me weather stripping tell',
#  'best care insurance is long term the what',
#  'best care insurance is long term what the',
#  'best care insurance is long the term what',
#  'best care insurance is long the what term',
#  'best care insurance is long what term the',
#  'about black history me tell',
#  'about black history tell me',
#  'about black me history tell',
#  'about black me tell history',
#  'about black tell history me',
#  'about hotels in me new tell york',
#  'about hotels in me new york tell',
#  'about hotels in me tell new york',
#  'about hotels in me tell york new',
#  'about hotels in me york new tell',
#  'about city kansas me mo tell',
#  'about city kansas me tell mo',
#  'about city kansas mo me tell',
#  'about city kansas mo tell me',
#  'about city kansas tell me mo',
#  'annual credit do free get how i my report',
#  'annual credit do free get how i report my',
#  'annual credit do free get how my i report',
#  'annual credit do free get how my report i',
#  'annual credit do free get how report i my',
#  'about me tell unc',
#  'about me unc tell',
#  'about tell me unc',
#  'about tell unc me',
#  'about unc me tell',
#  'about me tell vanuatu',
#  'about me vanuatu tell',
#  'about tell me vanuatu',
#  'about tell vanuatu me',
#  'about vanuatu me tell',
#  'about internet me phone serices tell',
#  'about internet me phone tell serices',
#  'about internet me serices phone tell',
#  'about internet me serices tell phone',
#  'about internet me tell phone serices',
#  'about find gs information pay rate the',
#  'about find gs information pay the rate',
#  'about find gs information rate pay the',
#  'about find gs information rate the pay',
#  'about find gs information the pay rate',
#  'current me take the to',
#  'current me take to the',
#  'current me the take to',
#  'current me the to take',
#  'current me to take the',
#  'a about information me sore tell throat',
#  'a about information me sore throat tell',
#  'a about information me tell sore throat',
#  'a about information me tell throat sore',
#  'a about information me throat sore tell',
#  'about flower idaho me state tell',
#  'about flower idaho me tell state',
#  'about flower idaho state me tell',
#  'about flower idaho state tell me',
#  'about flower idaho tell me state',
#  'about fairgrounds indiana me more state tell',
#  'about fairgrounds indiana me more tell state',
#  'about fairgrounds indiana me state more tell',
#  'about fairgrounds indiana me state tell more',
#  'about fairgrounds indiana me tell more state',
#  'about fybromyalgia me tell',
#  'about fybromyalgia tell me',
#  'about me fybromyalgia tell',
#  'about me tell fybromyalgia',
#  'about tell fybromyalgia me',
#  'and casino find french information lick on resort',
#  'and casino find french information lick resort on',
#  'and casino find french information on lick resort',
#  'and casino find french information on resort lick',
#  'and casino find french information resort lick on',
#  'about information me tell volvo',
#  'about information me volvo tell',
#  'about information tell me volvo',
#  'about information tell volvo me',
#  'about information volvo me tell',
#  'for im information looking on rick warren',
#  'for im information looking on warren rick',
#  'for im information looking rick on warren',
#  'for im information looking rick warren on',
#  'for im information looking warren on rick',
#  'is what yahoo',
#  'is yahoo what',
#  'what is yahoo',
#  'what yahoo is',
#  'yahoo is what',
#  'can heart how i lower my rate',
#  'can heart how i lower rate my',
#  'can heart how i my lower rate',
#  'can heart how i my rate lower',
#  'can heart how i rate lower my',
#  'im in interested inuyasha',
#  'im in inuyasha interested',
#  'im interested in inuyasha',
#  'im interested inuyasha in',
#  'im inuyasha in interested',
#  '2 about games me ps tell',
#  '2 about games me tell ps',
#  '2 about games ps me tell',
#  '2 about games ps tell me',
#  '2 about games tell me ps',
#  'get how organised to',
#  'get how to organised',
#  'get organised how to',
#  'get organised to how',
#  'get to how organised',
#  'about diabetes education find information me',
#  'about diabetes education find me information',
#  'about diabetes education information find me',
#  'about diabetes education information me find',
#  'about diabetes education me find information',
#  'about atari find information',
#  'about atari information find',
#  'about find atari information',
#  'about find information atari',
#  'about information atari find',
#  'and design for hosting im information looking on web',
#  'and design for hosting im information looking web on',
#  'and design for hosting im information on looking web',
#  'and design for hosting im information on web looking',
#  'and design for hosting im information web looking on',
#  'about elliptical find information trainer',
#  'about elliptical find trainer information',
#  'about elliptical information find trainer',
#  'about elliptical information trainer find',
#  'about elliptical trainer find information',
#  'about cell me phones tell',
#  'about cell me tell phones',
#  'about cell phones me tell',
#  'about cell phones tell me',
#  'about cell tell me phones',
#  'buy gps i receiver should which',
#  'buy gps i receiver which should',
#  'buy gps i should receiver which',
#  'buy gps i should which receiver',
#  'buy gps i which receiver should',
#  'a adopt can dog how i',
#  'a adopt can dog i how',
#  'a adopt can how dog i',
#  'a adopt can how i dog',
#  'a adopt can i dog how',
#  'about disneyland give hotel information me',
#  'about disneyland give hotel me information',
#  'about disneyland give information hotel me',
#  'about disneyland give information me hotel',
#  'about disneyland give me hotel information',
#  'change house how in the the to toilet',
#  'change house how in the the toilet to',
#  'change house how in the to the toilet',
#  'change house how in the to toilet the',
#  'change house how in the toilet the to',
#  'are in jobs michigan popular the what',
#  'are in jobs michigan popular what the',
#  'are in jobs michigan the popular what',
#  'are in jobs michigan the what popular',
#  'are in jobs michigan what popular the',
#  'for i looking m man music the ’',
#  'for i looking m man music ’ the',
#  'for i looking m man the music ’',
#  'for i looking m man the ’ music',
#  'for i looking m man ’ music the',
#  'about find garden information secret the',
#  'about find garden information the secret',
#  'about find garden secret information the',
#  'about find garden secret the information',
#  'about find garden the information secret',
#  'about alexian brothers give hospitals information me',
#  'about alexian brothers give hospitals me information',
#  'about alexian brothers give information hospitals me',
#  'about alexian brothers give information me hospitals',
#  'about alexian brothers give me hospitals information',
#  'about antenna me tell wilson',
#  'about antenna me wilson tell',
#  'about antenna tell me wilson',
#  'about antenna tell wilson me',
#  'about antenna wilson me tell',
#  'designs flame for im looking',
#  'designs flame for looking im',
#  'designs flame im for looking',
#  'designs flame im looking for',
#  'designs flame looking for im',
#  'about college find information mitchell',
#  'about college find mitchell information',
#  'about college information find mitchell',
#  'about college information mitchell find',
#  'about college mitchell find information',
#  'dog heat info on',
#  'dog heat on info',
#  'dog info heat on',
#  'dog info on heat',
#  'dog on heat info',
#  'about avp me tell',
#  'about avp tell me',
#  'about me avp tell',
#  'about me tell avp',
#  'about tell avp me',
#  'channel discovery store',
#  'channel store discovery',
#  'discovery channel store',
#  'discovery store channel',
#  'store channel discovery',
#  'for im information looking of on president states the the united',
#  'for im information looking of on president states the united the',
#  'for im information looking of on president states united the the',
#  'for im information looking of on president the states the united',
#  'for im information looking of on president the states united the',
#  'about iron me tell',
#  'about iron tell me',
#  'about me iron tell',
#  'about me tell iron',
#  'about tell iron me',
#  'about charleston me sc tell uss yorktown',
#  'about charleston me sc tell yorktown uss',
#  'about charleston me sc uss tell yorktown',
#  'about charleston me sc uss yorktown tell',
#  'about charleston me sc yorktown tell uss',
#  'about ct jobs me tell',
#  'about ct jobs tell me',
#  'about ct me jobs tell',
#  'about ct me tell jobs',
#  'about ct tell jobs me',
#  'about find information penguins',
#  'about find penguins information',
#  'about information find penguins',
#  'about information penguins find',
#  'about penguins find information',
#  'a build fence how to',
#  'a build fence to how',
#  'a build how fence to',
#  'a build how to fence',
#  'a build to fence how',
#  'city kansas me more on railroad tell',
#  'city kansas me more on tell railroad',
#  'city kansas me more railroad on tell',
#  'city kansas me more railroad tell on',
#  'city kansas me more tell on railroad',
#  'about bellevue me tell',
#  'about bellevue tell me',
#  'about me bellevue tell',
#  'about me tell bellevue',
#  'about tell bellevue me',
#  'for i information looking m on worm ’',
#  'for i information looking m on ’ worm',
#  'for i information looking m worm on ’',
#  'for i information looking m worm ’ on',
#  'for i information looking m ’ on worm',
#  'about find flushing information',
#  'about find information flushing',
#  'about flushing find information',
#  'about flushing information find',
#  'about information find flushing',
#  'about korean language me tell',
#  'about korean language tell me',
#  'about korean me language tell',
#  'about korean me tell language',
#  'about korean tell language me',
#  'i income information need on online return tax',
#  'i income information need on online tax return',
#  'i income information need on return online tax',
#  'i income information need on return tax online',
#  'i income information need on tax online return',
#  'for im information levels looking on vldl',
#  'for im information levels looking vldl on',
#  'for im information levels on looking vldl',
#  'for im information levels on vldl looking',
#  'for im information levels vldl looking on',
#  'about find information me pvc',
#  'about find information pvc me',
#  'about find me information pvc',
#  'about find me pvc information',
#  'about find pvc information me',
#  'find for instructions me sewing',
#  'find for instructions sewing me',
#  'find for me instructions sewing',
#  'find for me sewing instructions',
#  'find for sewing instructions me',
#  'be be is not or question that the to to',
#  'be be is not or question that to the to',
#  'be be is not or question that to to the',
#  'be be is not or question the that to to',
#  'be be is not or question the to that to',
#  'about find information sun the',
#  'about find information the sun',
#  'about find sun information the',
#  'about find sun the information',
#  'about find the information sun',
#  'about me neil tell young',
#  'about me neil young tell',
#  'about me tell neil young',
#  'about me tell young neil',
#  'about me young neil tell',
#  'about find information tornadoes',
#  'about find tornadoes information',
#  'about information find tornadoes',
#  'about information tornadoes find',
#  'about tornadoes find information',
#  'about bobcat information',
#  'about information bobcat',
#  'bobcat about information',
#  'bobcat information about',
#  'information about bobcat',
#  'for im keyboard looking reviews',
#  'for im keyboard reviews looking',
#  'for im looking keyboard reviews',
#  'for im looking reviews keyboard',
#  'for im reviews keyboard looking',
#  'about afganistan me tell',
#  'about afganistan tell me',
#  'about me afganistan tell',
#  'about me tell afganistan',
#  'about tell afganistan me',
#  'about id joints learn like to',
#  'about id joints learn to like',
#  'about id joints like learn to',
#  'about id joints like to learn',
#  'about id joints to learn like',
#  'are continental plates what',
#  'are continental what plates',
#  'are plates continental what',
#  'are plates what continental',
#  'are what continental plates',
#  'about can find forearm i information pain where',
#  'about can find forearm i information where pain',
#  'about can find forearm i pain information where',
#  'about can find forearm i pain where information',
#  'about can find forearm i where information pain',
#  'give information me ocd on',
#  'give information me on ocd',
#  'give information ocd me on',
#  'give information ocd on me',
#  'give information on me ocd',
#  'am car for i looking of parts sources used',
#  'am car for i looking of parts used sources',
#  'am car for i looking of sources parts used',
#  'am car for i looking of sources used parts',
#  'am car for i looking of used parts sources',
#  'about me mgb tell',
#  'about me tell mgb',
#  'about mgb me tell',
#  'about mgb tell me',
#  'about tell me mgb',
#  'about information raffles',
#  'about raffles information',
#  'information about raffles',
#  'information raffles about',
#  'raffles about information',
#  'about me rice tell',
#  'about me tell rice',
#  'about rice me tell',
#  'about rice tell me',
#  'about tell me rice',
#  'about africa for im information looking south',
#  'about africa for im information south looking',
#  'about africa for im looking information south',
#  'about africa for im looking south information',
#  'about africa for im south information looking',
#  'find information me on sat',
#  'find information me sat on',
#  'find information on me sat',
#  'find information on sat me',
#  'find information sat me on',
#  'about me more satilies tell',
#  'about me more tell satilies',
#  'about me satilies more tell',
#  'about me satilies tell more',
#  'about me tell more satilies',
#  'average charitable donation is what',
#  'average charitable donation what is',
#  'average charitable is donation what',
#  'average charitable is what donation',
#  'average charitable what donation is',
#  'for is known madagascar what',
#  'for is known what madagascar',
#  'for is madagascar known what',
#  'for is madagascar what known',
#  'for is what known madagascar',
#  'about activities day earth kids me tell',
#  'about activities day earth kids tell me',
#  'about activities day earth me kids tell',
#  'about activities day earth me tell kids',
#  'about activities day earth tell kids me',
#  '2008 college electoral results was what',
#  '2008 college electoral results what was',
#  '2008 college electoral was results what',
#  '2008 college electoral was what results',
#  '2008 college electoral what results was',
#  'food is pyramid usda what',
#  'food is pyramid what usda',
#  'food is usda pyramid what',
#  'food is usda what pyramid',
#  'food is what pyramid usda',
#  'about chicken from making me scratch soup tell',
#  'about chicken from making me scratch tell soup',
#  'about chicken from making me soup scratch tell',
#  'about chicken from making me soup tell scratch',
#  'about chicken from making me tell scratch soup',
#  'i lyrics survive will',
#  'i lyrics will survive',
#  'i survive lyrics will',
#  'i survive will lyrics',
#  'i will lyrics survive',
#  'about hawain me more tell volcanos',
#  'about hawain me more volcanos tell',
#  'about hawain me tell more volcanos',
#  'about hawain me tell volcanos more',
#  'about hawain me volcanos more tell',
#  'are deadly seven sins the what',
#  'are deadly seven sins what the',
#  'are deadly seven the sins what',
#  'are deadly seven the what sins',
#  'are deadly seven what sins the',
#  'flooding for hurricane im in information irene looking manville nj on',
#  'flooding for hurricane im in information irene looking manville on nj',
#  'flooding for hurricane im in information irene looking nj manville on',
#  'flooding for hurricane im in information irene looking nj on manville',
#  'flooding for hurricane im in information irene looking on manville nj',
#  'about cow disease humans in mad me of symptoms tell',
#  'about cow disease humans in mad me of tell symptoms',
#  'about cow disease humans in mad me symptoms of tell',
#  'about cow disease humans in mad me symptoms tell of',
#  'about cow disease humans in mad me tell of symptoms',
#  'biography frank lets lloyd see wright',
#  'biography frank lets lloyd wright see',
#  'biography frank lets see lloyd wright',
#  'biography frank lets see wright lloyd',
#  'biography frank lets wright lloyd see',
#  'how to use wiki',
#  'how to wiki use',
#  'how use to wiki',
#  'how use wiki to',
#  'how wiki to use',
#  'about battles carolina civil in me south tell war',
#  'about battles carolina civil in me south war tell',
#  'about battles carolina civil in me tell south war',
#  'about battles carolina civil in me tell war south',
#  'about battles carolina civil in me war south tell',
#  'bites how identifying is spider',
#  'bites how identifying spider is',
#  'bites how is identifying spider',
#  'bites how is spider identifying',
#  'bites how spider identifying is',
#  'about evidence evolution for me tell',
#  'about evidence evolution for tell me',
#  'about evidence evolution me for tell',
#  'about evidence evolution me tell for',
#  'about evidence evolution tell for me',
#  'about alabama formerly give in information living me tribe',
#  'about alabama formerly give in information living tribe me',
#  'about alabama formerly give in information me living tribe',
#  'about alabama formerly give in information me tribe living',
#  'about alabama formerly give in information tribe living me',
#  'attack find heart of symptoms',
#  'attack find heart symptoms of',
#  'attack find of heart symptoms',
#  'attack find of symptoms heart',
#  'attack find symptoms heart of',
#  'can history how i internet my view',
#  'can history how i internet view my',
#  'can history how i my internet view',
#  'can history how i my view internet',
#  'can history how i view internet my',
#  'find morel mushrooms to where',
#  'find morel mushrooms where to',
#  'find morel to mushrooms where',
#  'find morel to where mushrooms',
#  'find morel where mushrooms to',
#  'common drugs for im information looking on schizophrenia',
#  'common drugs for im information looking schizophrenia on',
#  'common drugs for im information on looking schizophrenia',
#  'common drugs for im information on schizophrenia looking',
#  'common drugs for im information schizophrenia looking on',
#  'acid batteries for im information lead looking on recycling',
#  'acid batteries for im information lead looking recycling on',
#  'acid batteries for im information lead on looking recycling',
#  'acid batteries for im information lead on recycling looking',
#  'acid batteries for im information lead recycling looking on',
#  'can cheap find i internet where',
#  'can cheap find i where internet',
#  'can cheap find internet i where',
#  'can cheap find internet where i',
#  'can cheap find where i internet',
#  'about cj madam me tell walker',
#  'about cj madam me walker tell',
#  'about cj madam tell me walker',
#  'about cj madam tell walker me',
#  'about cj madam walker me tell',
#  'child in indiana support',
#  'child in support indiana',
#  'child indiana in support',
#  'child indiana support in',
#  'child support in indiana',
#  'about and me reach sit tell test the',
#  'about and me reach sit tell the test',
#  'about and me reach sit test tell the',
#  'about and me reach sit test the tell',
#  'about and me reach sit the tell test',
#  'are characteristics of uranus what',
#  'are characteristics of what uranus',
#  'are characteristics uranus of what',
#  'are characteristics uranus what of',
#  'are characteristics what of uranus',
#  'about electronic me shoot skeet tell',
#  'about electronic me shoot tell skeet',
#  'about electronic me skeet shoot tell',
#  'about electronic me skeet tell shoot',
#  'about electronic me tell shoot skeet',
#  'become can can highway how one patrol',
#  'become can can highway how patrol one',
#  'become can can highway one how patrol',
#  'become can can highway one patrol how',
#  'become can can highway patrol how one',
#  '403b a is what',
#  '403b a what is',
#  '403b is a what',
#  '403b is what a',
#  '403b what a is',
#  'about find information last me painting supper the',
#  'about find information last me painting the supper',
#  'about find information last me supper painting the',
#  'about find information last me supper the painting',
#  'about find information last me the painting supper',
#  'band beatles for im information looking on rock the',
#  'band beatles for im information looking on the rock',
#  'band beatles for im information looking rock on the',
#  'band beatles for im information looking rock the on',
#  'band beatles for im information looking the on rock',
#  'about for furniture me small spaces tell',
#  'about for furniture me small tell spaces',
#  'about for furniture me spaces small tell',
#  'about for furniture me spaces tell small',
#  'about for furniture me tell small spaces',
#  'im in interested poker tournaments',
#  'im in interested tournaments poker',
#  'im in poker interested tournaments',
#  'im in poker tournaments interested',
#  'im in tournaments interested poker',
#  'about me scooters tell',
#  'about me tell scooters',
#  'about scooters me tell',
#  'about scooters tell me',
#  'about tell me scooters',
#  'about howard me ron tell',
#  'about howard me tell ron',
#  'about howard ron me tell',
#  'about howard ron tell me',
#  'about howard tell me ron',
#  'a becoming for im information looking on paralegal',
#  'a becoming for im information looking paralegal on',
#  'a becoming for im information on looking paralegal',
#  'a becoming for im information on paralegal looking',
#  'a becoming for im information paralegal looking on',
#  'cook how pork tenderlion to',
#  'cook how pork to tenderlion',
#  'cook how tenderlion pork to',
#  'cook how tenderlion to pork',
#  'cook how to pork tenderlion',
#  'coins i in interested m old ’',
#  'coins i in interested m ’ old',
#  'coins i in interested old m ’',
#  'coins i in interested old ’ m',
#  'coins i in interested ’ m old',
#  'can how i quick smoking',
#  'can how i smoking quick',
#  'can how quick i smoking',
#  'can how quick smoking i',
#  'can how smoking i quick',
#  'civil i in interested m movement right ’',
#  'civil i in interested m movement ’ right',
#  'civil i in interested m right movement ’',
#  'civil i in interested m right ’ movement',
#  'civil i in interested m ’ movement right',
#  'condos find florida in',
#  'condos find in florida',
#  'condos florida find in',
#  'condos florida in find',
#  'condos in find florida',
#  'about breeds designer dog me tell',
#  'about breeds designer dog tell me',
#  'about breeds designer me dog tell',
#  'about breeds designer me tell dog',
#  'about breeds designer tell dog me',
#  'about center convention county for information looking orange the',
#  'about center convention county for information looking the orange',
#  'about center convention county for information orange looking the',
#  'about center convention county for information orange the looking',
#  'about center convention county for information the looking orange',
#  'about annuity for me more tax tell usa',
#  'about annuity for me more tax usa tell',
#  'about annuity for me more tell tax usa',
#  'about annuity for me more tell usa tax',
#  'about annuity for me more usa tax tell',
#  'about border me patrol tell texas',
#  'about border me patrol texas tell',
#  'about border me tell patrol texas',
#  'about border me tell texas patrol',
#  'about border me texas patrol tell',
#  'about id learn like moths to',
#  'about id learn like to moths',
#  'about id learn moths like to',
#  'about id learn moths to like',
#  'about id learn to like moths',
#  'air give information me travel',
#  'air give information travel me',
#  'air give me information travel',
#  'air give me travel information',
#  'air give travel information me',
#  'find gardens information on raised',
#  'find gardens information raised on',
#  'find gardens on information raised',
#  'find gardens on raised information',
#  'find gardens raised information on',
#  'dieting for im information looking on',
#  'dieting for im information on looking',
#  'dieting for im looking information on',
#  'dieting for im looking on information',
#  'dieting for im on information looking',
#  'about bart me sf tell',
#  'about bart me tell sf',
#  'about bart sf me tell',
#  'about bart sf tell me',
#  'about bart tell me sf',
#  'invented music who',
#  'invented who music',
#  'music invented who',
#  'music who invented',
#  'who invented music',
#  'about er me show television tell',
#  'about er me show tell television',
#  'about er me television show tell',
#  'about er me television tell show',
#  'about er me tell show television',
#  'about find information the wall',
#  'about find information wall the',
#  'about find the information wall',
#  'about find the wall information',
#  'about find wall information the',
#  'about give information me titan',
#  'about give information titan me',
#  'about give me information titan',
#  'about give me titan information',
#  'about give titan information me',
#  'find les me miserables of reviews the',
#  'find les me miserables of the reviews',
#  'find les me miserables reviews of the',
#  'find les me miserables reviews the of',
#  'find les me miserables the of reviews',
#  'about benefits chocolate dark health me tell',
#  'about benefits chocolate dark health tell me',
#  'about benefits chocolate dark me health tell',
#  'about benefits chocolate dark me tell health',
#  'about benefits chocolate dark tell health me',
#  'bio bush george me of sr tell',
#  'bio bush george me of tell sr',
#  'bio bush george me sr of tell',
#  'bio bush george me sr tell of',
#  'bio bush george me tell of sr',
#  'about me more presidents tell us',
#  'about me more presidents us tell',
#  'about me more tell presidents us',
#  'about me more tell us presidents',
#  'about me more us presidents tell',
#  'a about folk for me remedies sore tell throat',
#  'a about folk for me remedies sore throat tell',
#  'a about folk for me remedies tell sore throat',
#  'a about folk for me remedies tell throat sore',
#  'a about folk for me remedies throat sore tell',
#  'a do how knot tie windsor you',
#  'a do how knot tie you windsor',
#  'a do how knot windsor tie you',
#  'a do how knot windsor you tie',
#  'a do how knot you tie windsor']

# %%
inputs_enc = []
for req in inputs:
    inputs_enc.append(roberta.encode(req))

# %%
inputs_enc[3]
# Out:
# tensor([   0, 9006,  284,  162, 1137, 3907, 6168, 2583,    2])

# %%
roberta.extract_features(inputs)
# Out:
# tensor([[[-0.0109,  0.0153,  0.0858,  ...,  0.0126,  0.1339,  0.0440],
#          [-0.0134,  0.1727, -0.1304,  ...,  0.0917, -0.0282,  0.1001],
#          [ 0.6296, -0.4084, -0.0844,  ..., -0.2051,  0.1361,  1.3963],
#          ...,
#          [-0.0194,  0.0678,  0.5043,  ..., -0.3590,  1.5590,  1.0416],
#          [ 0.0337,  0.1827, -0.0480,  ..., -0.2606,  0.3240,  0.4156],
#          [ 0.0660, -0.0147,  0.1079,  ..., -0.0040,  0.1158,  0.0755]]],
#        grad_fn=<TransposeBackward0>)

# %%
inputs_enc = [roberta.extract_features(input) for input in inputs_enc]

# %%
inputs_enc[0].shape

# %%
max_len = 0
for i in range(len(inputs_enc)):
    if inputs_enc[i].shape[1]>max_len:
        max_len = inputs_enc[i].shape[1]

# %%
max_len = 19

# %%
inputs_enc = [torch.squeeze(input) for input in inputs_enc]

# %%
inputs_enc_padded =  torch.zeros((len(inputs_enc),max_len,embed_size), dtype=float)

# %%
for i in tqdm(range(len(inputs_enc))):
    pad_length = max_len - inputs_enc[i].shape[0]
    inputs_enc_padded[i] = torch.cat((inputs_enc[i],torch.zeros((pad_length, embed_size))))

# %%
inputs_enc_padded

# %%
torch.save(inputs_enc_padded, 'train_embeds_roberta_augmented.pt')

# %%
labels_aug

# %%
np.save('labels_aug_roberta.npy', labels_aug)

# %%
df_dev = pd.read_table(data_dir + "dev.tsv", sep = '\t').drop_duplicates('topic_id')
init_requests_dev = df_dev['initial_request'].to_numpy(dtype = str)
topic_ids_dev = df_dev['topic_id'].to_numpy(dtype = int)
clarification_need_dev = df_dev['clarification_need'].to_numpy(dtype = int)
req_data_dev = [(topic_ids_dev[i], init_requests_dev[i], clarification_need_dev[i]) for i in range(len(init_requests_dev))]
req_data_dev = np.array(req_data_dev)
inputs_dev = req_data_dev[:,1]
labels_dev = req_data_dev[:,2]
topics_dev = req_data_dev[:,0]
inputs_enc_dev = []
for req in inputs_dev:
    inputs_enc_dev.append(roberta.encode(req))

# %%
roberta.extract_features(inputs_enc_dev[3]).shape

# %%
inputs_enc_dev = [roberta.extract_features(input) for input in inputs_enc_dev]

# %%
max_len = 0
for i in range(len(inputs_enc_dev)):
    if inputs_enc_dev[i].shape[1]>max_len:
        max_len = inputs_enc_dev[i].shape[1]

# %%
max_len

# %%
inputs_enc_dev = [torch.squeeze(input) for input in inputs_enc_dev]
inputs_enc_padded_dev =  torch.zeros((len(inputs_enc_dev),max_len,embed_size), dtype=float)
for i in tqdm(range(len(inputs_enc_dev))):
    pad_length = max_len - inputs_enc_dev[i].shape[0]
    inputs_enc_padded_dev[i] = torch.cat((inputs_enc_dev[i],torch.zeros((pad_length, embed_size))))

# %%
inputs_enc_padded_dev.shape

# %%
torch.save(inputs_enc_padded_dev, 'dev_embeds_roberta.pt')

# %%
topics
